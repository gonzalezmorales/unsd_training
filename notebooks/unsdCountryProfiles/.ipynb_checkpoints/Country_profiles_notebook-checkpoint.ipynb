# %% [markdown]
# # Generate country profiles

# %% [markdown]
# Documenting the generation of country profiles

# %% [markdown]
# ### Load necessary libraries

# %%
import csv
import json
import urllib3  # allows to access a URL with python
import urllib
import re
import statistics
import math
import os

# %% [markdown]
# ### User parameters

# %%
os.chdir('C:\\Users\\L.GonzalezMorales\\Documents\\GitHub\\FIS4SDGs\\unsd\\country-profiles\\ProjectCountryProfilesPython\\') 
           
release = '2019.Q1.G.02' # Make sure to have the correct release here

# %% [markdown]
# ## Auxiliary funtions

# %% [markdown]
# ### Commercial rounding

# %%
def round_KFM(x, n):
    posneg = math.copysign(1, x)
    z = abs(x)*10**n
    z = z + 0.5
    z = math.trunc(z)
    z = z/10**n
    result = z * posneg
    return result

# %%
print(round_KFM(3.5023,2))
# Out:
# 3.5

# %% [markdown]
# #### Regular expression to capture numeric values (including those in scientific notation)
# The regex is
#
# ```
# -?      # an optional -
# \d+     # a series of digits
# (?:     # start non capturing group
#   \.    # a dot
#   \d+   # a series of digits
# )?
# (?:     # start non capturing group
#   e     # "e"
#   -?    # an optional -
#   \d+   # digits
# )?
# ```

# %%
def numeric_part(v):
    numeric_part_f = re.compile(r'-?\d+(?:\.\d+)?(?:e-?\d+)?')
    x = numeric_part_f.findall(v)
    if len(x) > 0:
        return float(x[0])
    else:
        return None

# %%
print(numeric_part('<4'))
print(numeric_part('abs'))
print(numeric_part('-23.2e2'))
print(numeric_part('-23.2e2 or more'))
# Out:
# 4.0
# None
# -2320.0
# -2320.0

# %%
def non_numeric_part(v):
    numeric_part_f = re.compile(r'-?\d+(?:\.\d+)?(?:e-?\d+)?')
    x = numeric_part_f.findall(v)
    if len(x) > 0:
        return v.replace(x[0],'')
    else:
        return v

# %%
print(non_numeric_part('<4'))
print(non_numeric_part('abs'))
print(non_numeric_part('-23.2e2'))
print(non_numeric_part('xsy-23.2e2 or more'))
# Out:
# <
# abs
#
# xsy or more

# %% [markdown]
# #### Disable insecure request warnings when using `urllib3`.

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# ## Main steps

# %% [markdown]
# ### (1) Read fact-builder conditions

# %%
fact_builder = []
with open('CountryProfileBuilder.txt', newline = '') as countryProfileBuilder:                                                                                          
    country_profile_builder = csv.DictReader(countryProfileBuilder, delimiter='\t')
    for row in country_profile_builder:
        fact_builder.append(dict(row))
        
fact_builder[1]
# Out:
# {'No.': '2',
#  'SDMX_CODE': 'SI_POV_EMP1',
#  'SeriesCode': 'SI_POV_EMP1',
#  'HubItemId': 'deb1f4a7e2e14d78a113c53cba2838de',
#  'Profile.Series': '1',
#  'Goal.ID': '1',
#  'Goal.Name': 'Goal 1: End poverty in all its forms everywhere',
#  'P.IndicatorCode': 'C010101',
#  'P.IndicatorName.2017': 'Employed population below international poverty line',
#  'Age': '15+',
#  'Location': '',
#  'Sex': 'BOTHSEX',
#  'Bounds': '',
#  'Education level': '',
#  'Type of product': '',
#  'Type of mobile technology': '',
#  'Type of speed': '',
#  'zero.removal': '1',
#  'Text.type': '2',
#  'unit1': '% ',
#  'unit2': '%',
#  'DA2.1': " of the country's workers and their families were living on less than 1.90 US dollars per person per day",
#  'DA2.2': '',
#  'DA3.1': " of the country's workers and their families were living on less than 1.90 US dollars per person per day",
#  'DA3.2': '',
#  'Down': ' down from ',
#  'Up': ' up from '}

# %% [markdown]
# ### (2) Create list of countries

# %%
countryArray = []
with open('CountryListXY.txt', newline = '') as countryListXY:                                                                                          
    countryListXY = csv.DictReader(countryListXY, delimiter='\t')
    for row in countryListXY:
        countryArray.append(dict(row))
        
    
print("Total number or countries: ", len(countryArray))
countryArray[0:1]
# Out:
# Total number or countries:  248
# [{'X': '66.02688198',
#   'Y': '33.83160199',
#   'ISO3CD': 'AFG',
#   'geoAreaCode': '4',
#   'geoAreaName': 'Afghanistan',
#   'UNMember': '1',
#   'CountryProfile': '1'}]

# %% [markdown]
# ### (3) Get the list of goals, targets and indicators

# %% [markdown]
# ##### 3.1 Start by creating a `PoolManager()` object using `urllib3`

# %%
http = urllib3.PoolManager()

response = http.request('GET', "https://unstats.un.org/SDGAPI/v1/sdg/Goal/List?includechildren=true")
indicator_framework = json.loads(response.data.decode('UTF-8'))

#print(indicator_framework[0])

# %%
goal_temp = indicator_framework[3]
goal_temp.keys()
print(goal_temp['code'])
print(goal_temp['title'])
print(goal_temp['description'])
# Out:
# 4
# Ensure inclusive and equitable quality education and promote lifelong learning opportunities for all
# Goal 4 focuses on the acquisition of foundational and higher-order skills; greater and more equitable access to technical and vocational education and training and higher education; training throughout life; and the knowledge, skills and values needed to function well and contribute to society.

# %%
print(goal_temp['targets'][0].keys())
print(goal_temp['targets'][0]['title'])
print(goal_temp['targets'][0]['description'])
# Out:
# dict_keys(['goal', 'code', 'title', 'description', 'uri', 'indicators'])
# By 2030, ensure that all girls and boys complete free, equitable and quality primary and secondary education leading to relevant and effective learning outcomes
# By 2030, ensure that all girls and boys complete free, equitable and quality primary and secondary education leading to relevant and effective learning outcomes

# %%
goal_temp['targets'][0]['indicators'][0].keys()
# Out:
# dict_keys(['goal', 'target', 'code', 'description', 'tier', 'uri', 'series'])

# %% [markdown]
# ##### 3.2 Flatten into a list of dictionaries

# %%
series_list = []

keys = ["goalCode", 
        "goalDesc",
        "targetCode",
        "targetDesc",
        "indicatorCode",
        "indicatorDesc",
        "indicatorTier",
        "seriesCode",
        "seriesDesc"
       ]

for g in indicator_framework:
    for t in g['targets']:
        for i in t['indicators']:
            for s in i['series']:
                if s['release'] == release:
                    values = [g['code'], g['title'],
                              t['code'], t['description'], 
                              i['code'], i['description'], i['tier'], 
                              s['code'], s['description']]
                    
                    keys_and_values = zip(keys, values)
                    serie_dic = {}
                    for key, value in keys_and_values:
                        serie_dic[key] = value
                    series_list.append(serie_dic)
                        

series_list[0]
# Out:
# {'goalCode': '1',
#  'goalDesc': 'End poverty in all its forms everywhere',
#  'targetCode': '1.1',
#  'targetDesc': 'By 2030, eradicate extreme poverty for all people everywhere, currently measured as people living on less than $1.25 a day',
#  'indicatorCode': '1.1.1',
#  'indicatorDesc': 'Proportion of population below the international poverty line, by sex, age, employment status and geographical location (urban/rural)',
#  'indicatorTier': '1',
#  'seriesCode': 'SI_POV_DAY1',
#  'seriesDesc': 'Proportion of population below international poverty line (%)'}

# %% [markdown]
# ### (4) Create country profiles

# %% [markdown]
# #### Get slice description

# %%
def get_slice_description(goalCode,seriesCode, seriesList):
    
   # slice_description = None
    
    for s in series_list:
        if (s['goalCode']==goalCode and s['seriesCode'] == seriesCode):
            slice_description = s
            continue
    
    return slice_description

# %%
get_slice_description('12','EN_MAT_DOMCMPC',series_list )
# Out:
# {'goalCode': '12',
#  'goalDesc': 'Ensure sustainable consumption and production patterns',
#  'targetCode': '12.2',
#  'targetDesc': 'By 2030, achieve the sustainable management and efficient use of natural resources',
#  'indicatorCode': '12.2.2',
#  'indicatorDesc': 'Domestic material consumption, domestic material consumption per capita, and domestic material consumption per GDP',
#  'indicatorTier': '1',
#  'seriesCode': 'EN_MAT_DOMCMPC',
#  'seriesDesc': 'Domestic material consumption per capita, by type of raw material (tonnes)'}

# %% [markdown]
# #### Get slice dimensions

# %%
def get_slice_dimensions(this_fact):

    slice_dimensions = {d: this_fact[d] for d in this_fact.keys() &
                        {'Age', 
                         'Location', 
                         'Sex', 
                         'Bounds', 
                         'Education level', 
                         'Type of product', 
                         'Type of mobile technology', 
                         'Type of speed'}}


    slice_dimensions = dict((k, v) for k, v in slice_dimensions.items() if v != '')

    return slice_dimensions

# %%
get_slice_dimensions(fact_builder[1])
# Out:
# {'Age': '15+', 'Sex': 'BOTHSEX'}

# %% [markdown]
# #### Collect fact data

# %%
def get_fact_data(this_fact, country_code):
    
    slice_dimensions = get_slice_dimensions(this_fact)
    
    series = this_fact['SeriesCode']

    baseURL = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/'

    if(len(slice_dimensions)>0):

        dimensions = ""
        first = True
        for d in slice_dimensions:
            dimension_name = d
            dimension_value = slice_dimensions[d]
            dimension_string = '{name:"'+ dimension_name +'",values:["'+ dimension_value + '"]}'
            if first:
                dimensions = dimension_string
                first = False
            else:
                dimensions = dimensions + "," + dimension_string

        dimensions = "[" + dimensions + "]"

        dimensions = urllib.parse.quote(dimensions, safe='')

        url = baseURL + series + "/GeoArea/" + country_code + "/DataSlice?dimensions=" + dimensions + ""

    else:

        url = baseURL + series + "/GeoArea/" + country_code + "/DataSlice"
        
    #----------------------------------------------------------------
    # Make a GET request using the http object that you just created 
    #----------------------------------------------------------------

    response = http.request('GET', url)

    data = json.loads(response.data.decode('UTF-8'))
    data = data['dimensions']
    
    for d in data[:]:
        if numeric_part(d['value']) is None:
            data.remove(d)
    
    if len(data) > 0:

        for d in data:
            d['year'] = d.pop('timePeriodStart')
            
            if 'Reporting Type' in d.keys():
                del(d['Reporting Type'])
            

    
    return data

# %%
get_fact_data(fact_builder[1],'484')
# Out:
# [{'value': '2.8', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2010'},
#  {'value': '3.7', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2004'},
#  {'value': '6.8', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2000'},
#  {'value': '4.8', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2002'},
#  {'value': '2.8', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2008'},
#  {'value': '2.2', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2012'},
#  {'value': '4.5', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2005'},
#  {'value': '2.2', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2006'},
#  {'value': '2.7', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2014'},
#  {'value': '1.4', 'Age': '15+', 'Sex': 'BOTHSEX', 'year': '2016'}]

# %% [markdown]
# #### Create vector of values

# %%
def data_values(data):
        
    years = []
    values = []
    values_numeric_part = []
    values_alpha_part = []
    values_is_censored = []
    
    
    for d in data:
    
        years.append(d['year'])
        values.append(d['value'])
        values_numeric_part.append(numeric_part(d['value']))
        values_alpha_part.append(non_numeric_part(d['value']))
        

    
    for i in range(len(values)):
        values[i] = values[i].replace("<", "less than ")
        values[i] = values[i].replace(">", "more than ")
        
    for i in range(len(values_alpha_part)):
        
        if values_alpha_part[i] != '':
            values_is_censored.append(True)
        else:
            values_is_censored.append(False)

    
    for i in range(len(values_numeric_part)):
        if values_numeric_part[i] is not None:
            if values_numeric_part[i] <0.99 :
                values_numeric_part[i] = round_KFM(values_numeric_part[i],2)
            if values_numeric_part[i] >= 0.99 and values_numeric_part[i] <= 10:
                values_numeric_part[i] = round_KFM(values_numeric_part[i],1)
            if values_numeric_part[i] >10 :
                values_numeric_part[i] = round_KFM(values_numeric_part[i],0)
                
    return years, values, values_numeric_part, values_alpha_part, values_is_censored

# %%
data_values(get_fact_data(fact_builder[1],'484'))
# Out:
# (['2010',
#   '2004',
#   '2000',
#   '2002',
#   '2008',
#   '2012',
#   '2005',
#   '2006',
#   '2014',
#   '2016'],
#  ['2.8', '3.7', '6.8', '4.8', '2.8', '2.2', '4.5', '2.2', '2.7', '1.4'],
#  [2.8, 3.7, 6.8, 4.8, 2.8, 2.2, 4.5, 2.2, 2.7, 1.4],
#  ['', '', '', '', '', '', '', '', '', ''],
#  [False, False, False, False, False, False, False, False, False, False])

# %%
count_country = 0

for this_country in countryArray:
    
    if this_country['CountryProfile'] != '1':
        continue
        
    count_country += 1
            
    country_profile = {}
    
    country_profile['release'] = release 

    country_code = str(this_country['geoAreaCode'])
    country_name = this_country['geoAreaName']
    
    country_profile['country_code'] = country_code
    country_profile['country_name'] = country_name
    country_profile['X'] = this_country['X']
    country_profile['Y'] = this_country['Y']
    
    print("Building country profile for ", country_name, " - (", count_country, ")")
    
    count_fact = 0
    
    goals = []
    
    
    for g in indicator_framework:
        
        goal = {}
        
        goal['goalCode'] = g['code']
    
        targets = []
        
        for t in g['targets']:
            
            target = {}
            
            target['targetCode'] = t['code']
        
            indicators = []
                
            for i in t['indicators']:
                
                indicator = {}
                indicator['indicatorCode'] = i['code']
                
                facts = []
                
                for s in i['series']:
                    
                    if s['release'] == release:
                
                        for this_fact in fact_builder:
                        
                            if this_fact['SeriesCode'] != s['code']:
                                continue

                            
                            if this_fact['Profile.Series'] != '1':
                                continue
                            
                            count_fact += 1

                            fact = {}

                            print(" -- ", country_name, " - (", count_country, "): Adding fact - (", count_fact, ") for series ", s['code'], "of goal ", g['code'])

                            fact['seriesCode'] = s['code']
                            fact['seriesTitle'] = s['description']
                            fact['hub'] = this_fact['HubItemId']

                            fact['slice_dimensions'] = get_slice_dimensions(this_fact)

                            #----------------------------------------------------------------
                            # Main fact calculation 
                            #----------------------------------------------------------------

                            years, values, values_numeric_part, values_alpha_part, values_is_censored =  data_values(get_fact_data(this_fact, country_code))

                            n = None      # number of observations available
                            y_min = None    # first year available
                            y_max = None    # most recent year available

                            value_y_min = None   # data value in the first year available
                            value_y_max = None   # data value in the most recent year available

                            value_y_min_num = None   # data value in the first year available
                            value_y_max_num = None   # data value in the most recent year available


                            value_median = None
                            dif_first_last = None
                            value_y_max_is_censored = None

                            prog = ""
                            prog_10 = ""
                            prog_12 = ""
                            prog_15 = ""
                            prog_mmr_min = ""
                            prog_mmr_max = ""

                            fact_text = ""

                            if(len(values)>0):

                                n = len(values)      # number of observations available
                                y_min = min(years)    # first year available
                                y_max = max(years)    # most recent year available

                                value_y_min = values[years.index(min(years))]   # data value in the first year available
                                value_y_max = values[years.index(max(years))]   # data value in the most recent year available

                                value_y_min_num = values_numeric_part[years.index(min(years))]   # data value in the first year available
                                value_y_max_num = values_numeric_part[years.index(max(years))]   # data value in the most recent year available

                                value_median = statistics.median(values_numeric_part)
                                dif_first_last = abs(values_numeric_part[years.index(min(years))] \
                                                     - values_numeric_part[years.index(max(years))])

                                value_y_max_is_censored = values_is_censored[years.index(max(years))]


                                #--------------------------------------------------------
                                #Information about status of progress: decline/increase?
                                #---------------------------------------------------------

                                if (value_y_min_num > value_y_max_num):
                                    prog = this_fact['Down'] 
                                    # Example: "declined from", "down from"
                                elif (value_y_min_num < value_y_max_num):
                                    prog = this_fact['Up']
                                    # Example: "increased from", "up from"
                                else:
                                    prog = ""

                                #print(prog)

                                #--------
                                # prog.15
                                #--------
                                if value_y_min_num < 0.01:
                                     prog_15 = "nearly no coverage"
                                else:
                                    prog_15 = str(value_y_min_num) + this_fact['unit1']

                                #--------
                                # prog.10
                                #--------

                                if value_y_max_num < 10:
                                    prog_10 = this_fact['Down']
                                else:
                                    prog_10 = this_fact['Up']

                                #--------
                                # prog.12
                                #--------

                                if value_y_max_num > 0:
                                    prog_12 = this_fact['Up'] 
                                else:
                                    prog_12 = this_fact['Down']


                                #-------------
                                # prog_mmr_min
                                #-------------
                                if value_y_min_num > 1: 
                                    prog_mmr_min = "deaths"
                                else:
                                    prog_mmr_min = "death"

                                #-------------
                                # prog_mmr_max
                                #-------------
                                if value_y_max_num > 1: 
                                    prog_mmr_max = "deaths" 
                                else:
                                    prog_mmr_max = "death"

                                #print("min = ",value_y_min_num)
                                #print("max = ",value_y_max_num)
                                #print("prog = ",prog)
                                #print(prog_15)
                                #print(prog_10)
                                #print(prog_12)
                                #print(prog_mmr_min)
                                #print(prog_mmr_max)


                                #--------------------------------------------------------------------

                                fact_text = ""

                                condition1 = dif_first_last >= 0.05 * abs(value_y_max_num) 
                                condition2 = not value_y_max_is_censored
                                condition3 = value_y_max_num >= .25*value_median
                                condition4 = int(y_min) < 2010
                                condition5 = n > 1

                                conditions = condition1 and condition2 and condition3 and condition4 and condition5

                                #print("condition1 = ", condition1)
                                #print("condition2 = ", condition2)
                                #print("condition3 = ", condition3)
                                #print("condition4 = ", condition4)
                                #print("condition5 = ", condition5)
                                #print("conditions = ", conditions)


                                if this_fact['Text.type'] =='1':
                                    if conditions:
                                        fact_text = this_fact['DA3.1'] + prog + "<span class='fact-value'>" + str(value_y_min) + "</span>" + " <span class='fact-unit'>" + this_fact['unit1']  + "</span>" + " in " +  "<span class='fact-year'>" + str(y_min) + "</span>" + " to " + "<span class='fact-value'>" + str(value_y_max) + this_fact['unit1']+ "</span> " +  " in " +  " <span class='fact-year'>" + str(y_max)  + "</span>" + "."
                                        fact_values = [ str(value_y_min), str(value_y_max)]
                                        fact_units =  [ this_fact['unit1'], this_fact['unit1']]
                                        fact_years =  [ str(y_min), str(y_max)]
                                    else:
                                        fact_text = this_fact['DA2.1'] +  "<span class='fact-value'>" + str(value_y_max) + "</span>" + " <span class='fact-unit'>" + this_fact['unit1'] + "</span>"  + " in " + "<span class='fact-year'>" + str(y_max)  + "</span>" + "."
                                        fact_values = [ str(value_y_max)]
                                        fact_units = [ this_fact['unit1']]
                                        fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '2':
                                    fact_text = "In " +  "<span class='fact-year'>" + y_max  + "</span>" + ", " +  "<span class='fact-value'>" + str(value_y_max) + "</span>" + " <span class='fact-unit'>" + this_fact['unit1'] + "</span> " + this_fact['DA2.1']
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '3':
                                    fact_text = "In " +  "<span class='fact-year'> " + y_max +  "</span> " + ", " + this_fact['DA2.1'] +   "<span class='fact-value'> " + str(value_y_max) + "</span>" + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> " + this_fact['DA2.2']
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '4':
                                    fact_text = this_fact['DA2.1']+  "<span class='fact-value'>"  + str(value_y_max) +  "</span> " + " in " + "<span class='fact-year'> " + y_max +  "</span> " + ", meaning "  + str(float(value_y_max) * 100) +  this_fact['DA2.2'] + "." 
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '7':
                                    fact_text = this_fact['DA2.1'] +  "<span class='fact-value'> " + str(value_y_max) +  "</span> " + " <span class='fact-unit'>" + this_fact['unit1']+  "</span> "  + " in "+  "<span class='fact-year'> "  + str(y_max)+  "</span> "  + "."
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '8':
                                    fact_text = "In "+  "<span class='fact-year'> "  + y_max+  "</span> "  + ", " +  "<span class='fact-value'> " + str(value_y_max)+  "</span> "  + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> "+ this_fact['DA2.1'] + "."
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '9':
                                    if conditions:
                                        fact_text = "In "+  "<span class='fact-year'> " + y_max +  "</span> "+ ", " + this_fact['DA2.1'] +  "<span class='fact-value'> "+ str(value_y_max) +  "</span> " + " <span class='fact-unit'>" + this_fact['unit1']+  "</span> " + ", " + prog +  "<span class='fact-value'> "+ str(value_y_min) +  "</span> " + " <span class='fact-unit'>" + this_fact['unit2'] +  "</span> " + " in "+  "<span class='fact-year'> " + y_min +  "</span> "
                                        fact_values = [ str(value_y_min) + this_fact['unit1'], str(value_y_max)+ this_fact['unit1']]
                                        fact_years =  [ str(y_min), str(y_max)]
                                    else:
                                        fact_text = "In "+  "<span class='fact-year'> " + y_max+  "</span> " + ", " + this_fact['DA2.1'] +  "<span class='fact-value'> "+ str(value_y_max) +  "</span> "  + " <span class='fact-unit'>" + this_fact['unit1']+  "</span> " + "."
                                        fact_values = [ str(value_y_max)]
                                        fact_units = [ this_fact['unit1']]
                                        fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '10':
                                    fact_text =  "In " +  "<span class='fact-year'> "+ y_max +  "</span> "+ ", " +  this_fact['DA2.1'] +  "<span class='fact-value'> "+ str(value_y_max) +  "</span> "  + " <span class='fact-unit'>" + this_fact['unit1']+  "</span> " + ". " + prog_10 
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '11':
                                    fact_text = "In "+  "<span class='fact-year'> " + y_max+  "</span> " + ", " +  this_fact['DA2.1']+  "<span class='fact-value'> " + str(value_y_max) +  "</span> "  + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> "+ ". "
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '12':
                                    fact_text = "As of " +  "<span class='fact-year'> "+ y_max +  "</span> "+ ", " + country_name + prog_12 + "."
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '13':
                                    fact_text =  "In " +  "<span class='fact-year'> "+ y_max+  "</span> " + ", " +  this_fact['DA2.1']+  "<span class='fact-value'> " + str(value_y_max) +  "</span> " + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> "+ this_fact['DA2.2'] + "."
                                    fact_values = [ str(value_y_max)]
                                    fact_units = [ this_fact['unit1']]
                                    fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '14':
                                    if conditions:
                                        fact_text = this_fact['DA3.1'] + prog +   "<span class='fact-value'>" + str(value_y_min) +  "</span> "  + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> " + " in " +  "<span class='fact-year'> "+ y_min+  "</span> " + " to "+  "<span class='fact-value'> " + str(value_y_max) +  "</span> "  + " <span class='fact-unit'>"  + this_fact['unit1'] +  "</span> "+ " in " +  "<span class='fact-year'> " + y_max+  "</span> " + "."
                                        fact_values = [ str(value_y_min), str(value_y_max)]
                                        fact_units = [ this_fact['unit1'], this_fact['unit1']]
                                        fact_years =  [ str(y_min), str(y_max)]
                                    else:
                                        fact_text = this_fact['DA2.1'] +  "<span class='fact-value'> "+ str(value_y_max)+  "</span> " + " <span class='fact-unit'>" + prog_mmr_max + this_fact['unit1'] +  "</span> " + " in "+  "<span class='fact-year'> " + str(y_max) +  "</span> "+ "."
                                        fact_values = [ str(value_y_max) + prog_mmr_max]
                                        fact_units = [ this_fact['unit1']]
                                        fact_years =  [ str(y_max)]

                                elif this_fact['Text.type'] == '15':
                                    if conditions:
                                        fact_text =  "In "+  "<span class='fact-year'> " + y_max +  "</span> "+ ", " +  this_fact['DA2.1'] +  "<span class='fact-value'> "+ str(value_y_max) +  "</span> " + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> " + "," + prog + prog_15 + " in "+  "<span class='fact-year'> " + y_min +  "</span> "+ "."
                                        fact_values = [ str(value_y_min), str(value_y_max)]
                                        fact_units = [ this_fact['unit1'], this_fact['unit1']]
                                        fact_years =  [ str(y_min), str(y_max)]
                                    else:
                                        fact_text =  "In "+  "<span class='fact-year'> " + y_max+  "</span> " + ", " +  this_fact['DA2.1'] +  "<span class='fact-value'> "+ str(value_y_max)+  "</span> "  + " <span class='fact-unit'>" + this_fact['unit1'] +  "</span> "+ "."
                                        fact_values = [ str(value_y_max)]
                                        fact_values = [ this_fact['unit1']]
                                        fact_years =  [ str(y_max)]


                                fact['text_type'] = this_fact['Text.type']
                                fact['fact_text'] = fact_text
                                fact['fact_values'] = fact_values
                                fact['fact_units'] = fact_units
                                fact['fact_years'] = fact_years
                                fact['data_years'] = years
                                fact['data_values'] = values
                                fact['data_is_censored'] = values_is_censored
                                fact['data_numeric_part'] = values_numeric_part
                                
                                if this_fact['Text.type'] == '10':
                                    fact['preferred_visualization'] = 'threshold'
                                elif this_fact['Text.type'] == '12':
                                    fact['preferred_visualization'] = 'boolean'
                                elif(len(values)>3):
                                    fact['preferred_visualization'] = 'time_series'
                                else:
                                    fact['preferred_visualization'] = 'singleton'
                                

                                #=======================  
                                facts.append(fact)

                if len(facts)>0:    
                    indicator['facts'] = facts
                    indicators.append(indicator)

            if len(indicators)>0:
                target['indicators'] = indicators
                targets.append(target)
        
        if len(targets)>0:
            goal['targets'] = targets
            goals.append(goal)
        
    country_profile['goals'] = goals
    

                   
    #=======================

    #with open('resolutions.json', 'w') as outfile:
    with open("country profile " + country_code + " " + country_name + ".json", 'w') as outfile:
        json.dump(country_profile, outfile, indent=4 )    

    #with open('resolutions.json', 'w') as outfile:
# Out:
# Building country profile for  Afghanistan  - ( 1 )
#  --  Afghanistan  - ( 1 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Afghanistan  - ( 1 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Afghanistan  - ( 1 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Afghanistan  - ( 1 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Afghanistan  - ( 1 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Afghanistan  - ( 1 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Afghanistan  - ( 1 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Afghanistan  - ( 1 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Afghanistan  - ( 1 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Afghanistan  - ( 1 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Afghanistan  - ( 1 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Afghanistan  - ( 1 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Afghanistan  - ( 1 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Afghanistan  - ( 1 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Afghanistan  - ( 1 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Afghanistan  - ( 1 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Afghanistan  - ( 1 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Afghanistan  - ( 1 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Afghanistan  - ( 1 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Afghanistan  - ( 1 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Afghanistan  - ( 1 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Afghanistan  - ( 1 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Afghanistan  - ( 1 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Afghanistan  - ( 1 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Afghanistan  - ( 1 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Afghanistan  - ( 1 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Afghanistan  - ( 1 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Afghanistan  - ( 1 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Afghanistan  - ( 1 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Afghanistan  - ( 1 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Afghanistan  - ( 1 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Afghanistan  - ( 1 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Afghanistan  - ( 1 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Afghanistan  - ( 1 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Afghanistan  - ( 1 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Afghanistan  - ( 1 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Afghanistan  - ( 1 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Afghanistan  - ( 1 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Afghanistan  - ( 1 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Afghanistan  - ( 1 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Afghanistan  - ( 1 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Afghanistan  - ( 1 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Albania  - ( 2 )
#  --  Albania  - ( 2 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Albania  - ( 2 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Albania  - ( 2 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Albania  - ( 2 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Albania  - ( 2 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Albania  - ( 2 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Albania  - ( 2 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Albania  - ( 2 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Albania  - ( 2 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Albania  - ( 2 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Albania  - ( 2 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Albania  - ( 2 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Albania  - ( 2 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Albania  - ( 2 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Albania  - ( 2 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Albania  - ( 2 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Albania  - ( 2 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Albania  - ( 2 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Albania  - ( 2 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Albania  - ( 2 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Albania  - ( 2 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Albania  - ( 2 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Albania  - ( 2 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Albania  - ( 2 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Albania  - ( 2 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Albania  - ( 2 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Albania  - ( 2 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Albania  - ( 2 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Albania  - ( 2 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Albania  - ( 2 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Albania  - ( 2 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Albania  - ( 2 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Albania  - ( 2 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Albania  - ( 2 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Albania  - ( 2 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Albania  - ( 2 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Albania  - ( 2 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Albania  - ( 2 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Albania  - ( 2 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Albania  - ( 2 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Albania  - ( 2 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Albania  - ( 2 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Antarctica  - ( 3 )
#  --  Antarctica  - ( 3 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Antarctica  - ( 3 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Antarctica  - ( 3 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Antarctica  - ( 3 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Antarctica  - ( 3 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Antarctica  - ( 3 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Antarctica  - ( 3 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Antarctica  - ( 3 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Antarctica  - ( 3 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Antarctica  - ( 3 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Antarctica  - ( 3 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Antarctica  - ( 3 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Antarctica  - ( 3 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Antarctica  - ( 3 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Antarctica  - ( 3 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Antarctica  - ( 3 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Antarctica  - ( 3 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Antarctica  - ( 3 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Antarctica  - ( 3 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Antarctica  - ( 3 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Antarctica  - ( 3 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Antarctica  - ( 3 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Antarctica  - ( 3 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Antarctica  - ( 3 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Antarctica  - ( 3 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Antarctica  - ( 3 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Antarctica  - ( 3 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Antarctica  - ( 3 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Antarctica  - ( 3 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Antarctica  - ( 3 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Antarctica  - ( 3 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Antarctica  - ( 3 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Antarctica  - ( 3 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Antarctica  - ( 3 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Antarctica  - ( 3 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Antarctica  - ( 3 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Antarctica  - ( 3 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Antarctica  - ( 3 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Antarctica  - ( 3 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Antarctica  - ( 3 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Antarctica  - ( 3 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Antarctica  - ( 3 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Algeria  - ( 4 )
#  --  Algeria  - ( 4 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Algeria  - ( 4 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Algeria  - ( 4 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Algeria  - ( 4 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Algeria  - ( 4 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Algeria  - ( 4 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Algeria  - ( 4 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Algeria  - ( 4 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Algeria  - ( 4 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Algeria  - ( 4 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Algeria  - ( 4 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Algeria  - ( 4 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Algeria  - ( 4 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Algeria  - ( 4 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Algeria  - ( 4 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Algeria  - ( 4 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Algeria  - ( 4 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Algeria  - ( 4 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Algeria  - ( 4 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Algeria  - ( 4 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Algeria  - ( 4 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Algeria  - ( 4 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Algeria  - ( 4 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Algeria  - ( 4 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Algeria  - ( 4 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Algeria  - ( 4 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Algeria  - ( 4 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Algeria  - ( 4 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Algeria  - ( 4 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Algeria  - ( 4 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Algeria  - ( 4 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Algeria  - ( 4 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Algeria  - ( 4 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Algeria  - ( 4 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Algeria  - ( 4 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Algeria  - ( 4 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Algeria  - ( 4 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Algeria  - ( 4 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Algeria  - ( 4 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Algeria  - ( 4 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Algeria  - ( 4 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Algeria  - ( 4 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  American Samoa  - ( 5 )
#  --  American Samoa  - ( 5 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  American Samoa  - ( 5 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  American Samoa  - ( 5 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  American Samoa  - ( 5 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  American Samoa  - ( 5 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  American Samoa  - ( 5 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  American Samoa  - ( 5 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  American Samoa  - ( 5 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  American Samoa  - ( 5 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  American Samoa  - ( 5 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  American Samoa  - ( 5 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  American Samoa  - ( 5 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  American Samoa  - ( 5 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  American Samoa  - ( 5 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  American Samoa  - ( 5 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  American Samoa  - ( 5 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  American Samoa  - ( 5 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  American Samoa  - ( 5 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  American Samoa  - ( 5 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  American Samoa  - ( 5 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  American Samoa  - ( 5 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  American Samoa  - ( 5 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  American Samoa  - ( 5 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  American Samoa  - ( 5 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  American Samoa  - ( 5 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  American Samoa  - ( 5 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  American Samoa  - ( 5 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  American Samoa  - ( 5 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  American Samoa  - ( 5 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  American Samoa  - ( 5 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  American Samoa  - ( 5 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  American Samoa  - ( 5 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  American Samoa  - ( 5 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  American Samoa  - ( 5 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  American Samoa  - ( 5 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  American Samoa  - ( 5 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  American Samoa  - ( 5 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  American Samoa  - ( 5 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  American Samoa  - ( 5 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  American Samoa  - ( 5 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  American Samoa  - ( 5 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  American Samoa  - ( 5 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Andorra  - ( 6 )
#  --  Andorra  - ( 6 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Andorra  - ( 6 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Andorra  - ( 6 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Andorra  - ( 6 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Andorra  - ( 6 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Andorra  - ( 6 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Andorra  - ( 6 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Andorra  - ( 6 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Andorra  - ( 6 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Andorra  - ( 6 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Andorra  - ( 6 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Andorra  - ( 6 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Andorra  - ( 6 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Andorra  - ( 6 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Andorra  - ( 6 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Andorra  - ( 6 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Andorra  - ( 6 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Andorra  - ( 6 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Andorra  - ( 6 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Andorra  - ( 6 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Andorra  - ( 6 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Andorra  - ( 6 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Andorra  - ( 6 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Andorra  - ( 6 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Andorra  - ( 6 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Andorra  - ( 6 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Andorra  - ( 6 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Andorra  - ( 6 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Andorra  - ( 6 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Andorra  - ( 6 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Andorra  - ( 6 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Andorra  - ( 6 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Andorra  - ( 6 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Andorra  - ( 6 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Andorra  - ( 6 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Andorra  - ( 6 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Andorra  - ( 6 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Andorra  - ( 6 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Andorra  - ( 6 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Andorra  - ( 6 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Andorra  - ( 6 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Andorra  - ( 6 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Angola  - ( 7 )
#  --  Angola  - ( 7 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Angola  - ( 7 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Angola  - ( 7 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Angola  - ( 7 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Angola  - ( 7 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Angola  - ( 7 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Angola  - ( 7 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Angola  - ( 7 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Angola  - ( 7 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Angola  - ( 7 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Angola  - ( 7 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Angola  - ( 7 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Angola  - ( 7 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Angola  - ( 7 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Angola  - ( 7 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Angola  - ( 7 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Angola  - ( 7 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Angola  - ( 7 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Angola  - ( 7 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Angola  - ( 7 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Angola  - ( 7 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Angola  - ( 7 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Angola  - ( 7 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Angola  - ( 7 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Angola  - ( 7 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Angola  - ( 7 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Angola  - ( 7 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Angola  - ( 7 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Angola  - ( 7 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Angola  - ( 7 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Angola  - ( 7 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Angola  - ( 7 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Angola  - ( 7 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Angola  - ( 7 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Angola  - ( 7 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Angola  - ( 7 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Angola  - ( 7 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Angola  - ( 7 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Angola  - ( 7 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Angola  - ( 7 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Angola  - ( 7 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Angola  - ( 7 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Antigua and Barbuda  - ( 8 )
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Antigua and Barbuda  - ( 8 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Azerbaijan  - ( 9 )
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Azerbaijan  - ( 9 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Argentina  - ( 10 )
#  --  Argentina  - ( 10 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Argentina  - ( 10 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Argentina  - ( 10 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Argentina  - ( 10 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Argentina  - ( 10 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Argentina  - ( 10 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Argentina  - ( 10 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Argentina  - ( 10 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Argentina  - ( 10 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Argentina  - ( 10 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Argentina  - ( 10 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Argentina  - ( 10 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Argentina  - ( 10 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Argentina  - ( 10 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Argentina  - ( 10 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Argentina  - ( 10 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Argentina  - ( 10 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Argentina  - ( 10 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Argentina  - ( 10 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Argentina  - ( 10 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Argentina  - ( 10 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Argentina  - ( 10 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Argentina  - ( 10 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Argentina  - ( 10 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Argentina  - ( 10 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Argentina  - ( 10 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Argentina  - ( 10 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Argentina  - ( 10 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Argentina  - ( 10 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Argentina  - ( 10 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Argentina  - ( 10 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Argentina  - ( 10 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Argentina  - ( 10 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Argentina  - ( 10 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Argentina  - ( 10 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Argentina  - ( 10 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Argentina  - ( 10 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Argentina  - ( 10 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Argentina  - ( 10 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Argentina  - ( 10 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Argentina  - ( 10 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Argentina  - ( 10 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Australia  - ( 11 )
#  --  Australia  - ( 11 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Australia  - ( 11 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Australia  - ( 11 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Australia  - ( 11 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Australia  - ( 11 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Australia  - ( 11 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Australia  - ( 11 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Australia  - ( 11 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Australia  - ( 11 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Australia  - ( 11 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Australia  - ( 11 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Australia  - ( 11 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Australia  - ( 11 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Australia  - ( 11 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Australia  - ( 11 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Australia  - ( 11 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Australia  - ( 11 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Australia  - ( 11 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Australia  - ( 11 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Australia  - ( 11 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Australia  - ( 11 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Australia  - ( 11 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Australia  - ( 11 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Australia  - ( 11 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Australia  - ( 11 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Australia  - ( 11 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Australia  - ( 11 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Australia  - ( 11 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Australia  - ( 11 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Australia  - ( 11 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Australia  - ( 11 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Australia  - ( 11 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Australia  - ( 11 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Australia  - ( 11 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Australia  - ( 11 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Australia  - ( 11 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Australia  - ( 11 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Australia  - ( 11 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Australia  - ( 11 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Australia  - ( 11 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Australia  - ( 11 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Australia  - ( 11 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Austria  - ( 12 )
#  --  Austria  - ( 12 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Austria  - ( 12 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Austria  - ( 12 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Austria  - ( 12 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Austria  - ( 12 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Austria  - ( 12 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Austria  - ( 12 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Austria  - ( 12 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Austria  - ( 12 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Austria  - ( 12 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Austria  - ( 12 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Austria  - ( 12 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Austria  - ( 12 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Austria  - ( 12 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Austria  - ( 12 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Austria  - ( 12 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Austria  - ( 12 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Austria  - ( 12 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Austria  - ( 12 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Austria  - ( 12 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Austria  - ( 12 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Austria  - ( 12 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Austria  - ( 12 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Austria  - ( 12 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Austria  - ( 12 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Austria  - ( 12 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Austria  - ( 12 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Austria  - ( 12 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Austria  - ( 12 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Austria  - ( 12 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Austria  - ( 12 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Austria  - ( 12 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Austria  - ( 12 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Austria  - ( 12 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Austria  - ( 12 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Austria  - ( 12 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Austria  - ( 12 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Austria  - ( 12 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Austria  - ( 12 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Austria  - ( 12 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Austria  - ( 12 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Austria  - ( 12 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Bahamas  - ( 13 )
#  --  Bahamas  - ( 13 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Bahamas  - ( 13 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Bahamas  - ( 13 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Bahamas  - ( 13 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Bahamas  - ( 13 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Bahamas  - ( 13 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Bahamas  - ( 13 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Bahamas  - ( 13 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Bahamas  - ( 13 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Bahamas  - ( 13 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Bahamas  - ( 13 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Bahamas  - ( 13 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Bahamas  - ( 13 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Bahamas  - ( 13 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Bahamas  - ( 13 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Bahamas  - ( 13 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Bahamas  - ( 13 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Bahamas  - ( 13 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Bahamas  - ( 13 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Bahamas  - ( 13 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Bahamas  - ( 13 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Bahamas  - ( 13 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Bahamas  - ( 13 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Bahamas  - ( 13 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Bahamas  - ( 13 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Bahamas  - ( 13 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Bahamas  - ( 13 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Bahamas  - ( 13 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Bahamas  - ( 13 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Bahamas  - ( 13 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Bahamas  - ( 13 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Bahamas  - ( 13 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Bahamas  - ( 13 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Bahamas  - ( 13 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Bahamas  - ( 13 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Bahamas  - ( 13 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Bahamas  - ( 13 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Bahamas  - ( 13 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Bahamas  - ( 13 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Bahamas  - ( 13 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Bahamas  - ( 13 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Bahamas  - ( 13 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Bahrain  - ( 14 )
#  --  Bahrain  - ( 14 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Bahrain  - ( 14 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Bahrain  - ( 14 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Bahrain  - ( 14 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Bahrain  - ( 14 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Bahrain  - ( 14 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Bahrain  - ( 14 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Bahrain  - ( 14 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Bahrain  - ( 14 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Bahrain  - ( 14 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Bahrain  - ( 14 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Bahrain  - ( 14 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Bahrain  - ( 14 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Bahrain  - ( 14 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Bahrain  - ( 14 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Bahrain  - ( 14 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Bahrain  - ( 14 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Bahrain  - ( 14 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Bahrain  - ( 14 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Bahrain  - ( 14 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Bahrain  - ( 14 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Bahrain  - ( 14 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Bahrain  - ( 14 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Bahrain  - ( 14 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Bahrain  - ( 14 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Bahrain  - ( 14 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Bahrain  - ( 14 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
# ...
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Venezuela (Bolivarian Republic of)  - ( 244 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Wallis and Futuna Islands  - ( 245 )
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Wallis and Futuna Islands  - ( 245 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Samoa  - ( 246 )
#  --  Samoa  - ( 246 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Samoa  - ( 246 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Samoa  - ( 246 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Samoa  - ( 246 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Samoa  - ( 246 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Samoa  - ( 246 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Samoa  - ( 246 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Samoa  - ( 246 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Samoa  - ( 246 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Samoa  - ( 246 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Samoa  - ( 246 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Samoa  - ( 246 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Samoa  - ( 246 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Samoa  - ( 246 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Samoa  - ( 246 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Samoa  - ( 246 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Samoa  - ( 246 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Samoa  - ( 246 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Samoa  - ( 246 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Samoa  - ( 246 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Samoa  - ( 246 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Samoa  - ( 246 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Samoa  - ( 246 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Samoa  - ( 246 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Samoa  - ( 246 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Samoa  - ( 246 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Samoa  - ( 246 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Samoa  - ( 246 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Samoa  - ( 246 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Samoa  - ( 246 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Samoa  - ( 246 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Samoa  - ( 246 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Samoa  - ( 246 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Samoa  - ( 246 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Samoa  - ( 246 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Samoa  - ( 246 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Samoa  - ( 246 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Samoa  - ( 246 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Samoa  - ( 246 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Samoa  - ( 246 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Samoa  - ( 246 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Samoa  - ( 246 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Yemen  - ( 247 )
#  --  Yemen  - ( 247 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Yemen  - ( 247 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Yemen  - ( 247 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Yemen  - ( 247 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Yemen  - ( 247 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Yemen  - ( 247 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Yemen  - ( 247 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Yemen  - ( 247 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Yemen  - ( 247 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Yemen  - ( 247 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Yemen  - ( 247 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Yemen  - ( 247 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Yemen  - ( 247 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Yemen  - ( 247 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Yemen  - ( 247 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Yemen  - ( 247 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Yemen  - ( 247 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Yemen  - ( 247 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Yemen  - ( 247 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Yemen  - ( 247 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Yemen  - ( 247 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Yemen  - ( 247 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Yemen  - ( 247 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Yemen  - ( 247 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Yemen  - ( 247 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Yemen  - ( 247 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Yemen  - ( 247 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Yemen  - ( 247 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Yemen  - ( 247 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Yemen  - ( 247 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Yemen  - ( 247 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Yemen  - ( 247 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Yemen  - ( 247 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Yemen  - ( 247 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Yemen  - ( 247 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Yemen  - ( 247 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Yemen  - ( 247 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Yemen  - ( 247 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Yemen  - ( 247 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Yemen  - ( 247 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Yemen  - ( 247 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Yemen  - ( 247 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
# Building country profile for  Zambia  - ( 248 )
#  --  Zambia  - ( 248 ): Adding fact - ( 1 ) for series  SI_POV_DAY1 of goal  1
#  --  Zambia  - ( 248 ): Adding fact - ( 2 ) for series  SI_POV_EMP1 of goal  1
#  --  Zambia  - ( 248 ): Adding fact - ( 3 ) for series  SI_POV_NAHC of goal  1
#  --  Zambia  - ( 248 ): Adding fact - ( 4 ) for series  SG_DSR_LEGREG of goal  1
#  --  Zambia  - ( 248 ): Adding fact - ( 5 ) for series  SN_ITK_DEFC of goal  2
#  --  Zambia  - ( 248 ): Adding fact - ( 6 ) for series  SH_STA_STUNT of goal  2
#  --  Zambia  - ( 248 ): Adding fact - ( 7 ) for series  SH_STA_OVRWGT of goal  2
#  --  Zambia  - ( 248 ): Adding fact - ( 8 ) for series  SH_STA_MMR of goal  3
#  --  Zambia  - ( 248 ): Adding fact - ( 9 ) for series  SH_DYN_MORT of goal  3
#  --  Zambia  - ( 248 ): Adding fact - ( 10 ) for series  SH_HIV_INCD of goal  3
#  --  Zambia  - ( 248 ): Adding fact - ( 11 ) for series  SH_DTH_NCOM of goal  3
#  --  Zambia  - ( 248 ): Adding fact - ( 12 ) for series  SE_PRE_PARTN of goal  4
#  --  Zambia  - ( 248 ): Adding fact - ( 13 ) for series  SE_GPI_MATACH of goal  4
#  --  Zambia  - ( 248 ): Adding fact - ( 14 ) for series  SE_GPI_REAACH of goal  4
#  --  Zambia  - ( 248 ): Adding fact - ( 15 ) for series  SP_DYN_MRBF18 of goal  5
#  --  Zambia  - ( 248 ): Adding fact - ( 16 ) for series  SG_GEN_PARL of goal  5
#  --  Zambia  - ( 248 ): Adding fact - ( 17 ) for series  SH_H2O_SAFE of goal  6
#  --  Zambia  - ( 248 ): Adding fact - ( 18 ) for series  SH_SAN_SAFE of goal  6
#  --  Zambia  - ( 248 ): Adding fact - ( 19 ) for series  EG_ELC_ACCS of goal  7
#  --  Zambia  - ( 248 ): Adding fact - ( 20 ) for series  EG_EGY_CLEAN of goal  7
#  --  Zambia  - ( 248 ): Adding fact - ( 21 ) for series  EN_MAT_DOMCMPC of goal  8
#  --  Zambia  - ( 248 ): Adding fact - ( 22 ) for series  SL_TLF_UEM of goal  8
#  --  Zambia  - ( 248 ): Adding fact - ( 23 ) for series  NY_GDP_PCAP of goal  8
#  --  Zambia  - ( 248 ): Adding fact - ( 24 ) for series  EN_ATM_CO2GDP of goal  9
#  --  Zambia  - ( 248 ): Adding fact - ( 25 ) for series  GB_XPD_RSDV of goal  9
#  --  Zambia  - ( 248 ): Adding fact - ( 26 ) for series  IT_MOB_NTWK of goal  9
#  --  Zambia  - ( 248 ): Adding fact - ( 27 ) for series  SL_EMP_GTOTL of goal  10
#  --  Zambia  - ( 248 ): Adding fact - ( 28 ) for series  EN_LND_SLUM of goal  11
#  --  Zambia  - ( 248 ): Adding fact - ( 29 ) for series  EN_ATM_PM25 of goal  11
#  --  Zambia  - ( 248 ): Adding fact - ( 30 ) for series  SG_DSR_LEGREG of goal  11
#  --  Zambia  - ( 248 ): Adding fact - ( 31 ) for series  EN_MAT_DOMCMPC of goal  12
#  --  Zambia  - ( 248 ): Adding fact - ( 32 ) for series  SG_DSR_LEGREG of goal  13
#  --  Zambia  - ( 248 ): Adding fact - ( 33 ) for series  ER_MRN_MARIN of goal  14
#  --  Zambia  - ( 248 ): Adding fact - ( 34 ) for series  AG_LND_FRST of goal  15
#  --  Zambia  - ( 248 ): Adding fact - ( 35 ) for series  ER_PTD_FRWRT of goal  15
#  --  Zambia  - ( 248 ): Adding fact - ( 36 ) for series  ER_PTD_TERRS of goal  15
#  --  Zambia  - ( 248 ): Adding fact - ( 37 ) for series  VC_IHR_PSRC of goal  16
#  --  Zambia  - ( 248 ): Adding fact - ( 38 ) for series  SG_REG_BRTH of goal  16
#  --  Zambia  - ( 248 ): Adding fact - ( 39 ) for series  BX_TRF_PWKR of goal  17
#  --  Zambia  - ( 248 ): Adding fact - ( 40 ) for series  DT_TDS_DECT of goal  17
#  --  Zambia  - ( 248 ): Adding fact - ( 41 ) for series  IT_NET_BBP of goal  17
#  --  Zambia  - ( 248 ): Adding fact - ( 42 ) for series  SG_STT_NSDSFND of goal  17
