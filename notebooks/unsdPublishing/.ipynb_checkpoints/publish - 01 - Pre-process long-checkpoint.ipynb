# %% [markdown]
# # Pre-processing script
# This script pulls SDG data from API and transforms it into csv files.
# The steps are:
# - Pull data from [API](https://unstats.un.org/SDGAPI/swagger/)
# - Join with geography
# - save as "long" table
# - pivot into "wide" format and split regional and country data

# %% [markdown]
# ### Load necessary libraries

# %%
import csv
import json
import urllib3  # allows to access a URL with python
import math
import os
import io
import collections
import hashlib
import numpy as np
import pandas as pd
import re
import xlsxwriter

# https://volderette.de/jupyter-notebook-tip-multiple-outputs/
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### User parameters

# %%
release = '2019.Q1.G.03' # Make sure to have the correct release here

dir_path = os.path.dirname(os.path.realpath('__file__'))
print(dir_path)

wd_dir = r'../../'
print('data inputs dir: ' + wd_dir)

# %% [markdown]
# ## Utilities

# %% [markdown]
# #### Convert string to camelCase

# %%
def camelCase(st):
    """
    https://stackoverflow.com/questions/8347048/camelcase-every-string-any-standard-library
    
    """
    output = ''.join(x for x in st.title() if x.isalnum())
    return output[0].lower() + output[1:]

# %% [markdown]
# #### Disable insecure request warnings when using `urllib3`.

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# #### Regular expression to capture numeric values (including those in scientific notation)
# The regex is
#
# ```
# -?      # an optional -
# \d+     # a series of digits
# (?:     # start non capturing group
#   \.    # a dot
#   \d+   # a series of digits
# )?
# (?:     # start non capturing group
#   e     # "e"
#   -?    # an optional -
#   \d+   # digits
# )?
# ```

# %%
def numeric_part(v):
    numeric_part_f = re.compile(r'-?\d+(?:\.\d+)?(?:e-?\d+)?')
    x = numeric_part_f.findall(v)
    if len(x) > 0:
        return float(x[0])
    else:
        return None

# %% [markdown]
# #### Compute a hash of a dictionary

# %%
def dict_hash(d):
    out = hashlib.md5()
    for key, value in d.items():
        out.update(key.encode('utf-8'))
        out.update(value.encode('utf-8'))
    return out.hexdigest()

# %% [markdown]
# #### Get unique dictionaries in a list

# %%
def unique_dicts(dictionary_list):

    uniques_map = {}

    for d in dictionary_list:
        uniques_map[dict_hash(d)] = d

    return list(uniques_map.values())

# %% [markdown]
# #### Extract subset of key-value pairs from Python dictionary object

# %%
def subdict_list(dict_list, keys_list, exclude = False):
    sub_d_list = []
    if exclude:
        for d in dict_list:
            sub_d= {k: d[k] for k in d.keys() if k not in keys_list}
            sub_d_list.append(sub_d)
    else:
        for d in dict_list:
            sub_d= {k: d[k] for k in keys_list}
            sub_d_list.append(sub_d)
    
    return sub_d_list

# %% [markdown]
# #### Get a dict from a list based on something inside the dict

# %%
def select_dict(dict_list, k, v):
    selected = []
    for d in dict_list:
        if d[k] == v:
            selected.append(d)
    return selected

# %% [markdown]
# ### List of countries to be plotted on a map (with XY coordinates)

# %%
def countryListXY(file):
    
    countryListXY = []
    
    with open(file, newline = '', encoding='latin-1') as countryList:                                                                                          
        countryList = csv.DictReader(countryList, delimiter='\t')
        for row in countryList:
            countryListXY.append(dict(row))
            
    countryListXY = pd.DataFrame(countryListXY).astype({'M49':'str'})
    
    return(countryListXY)

    #print(countryListXY[1])
    #for c in countryListXY:

# %%
countryListXY(wd_dir + 'globalResources/refAreas.txt').head(10)
# Out:
#   Country_Profile ISO3 M49 UN_Member             X             Y  \
# 0               1  AFG   4         1   66.02688198   33.83160199
# 1               1  ALB   8         1   20.06660928   41.13897007
# 2               1  ATA  10         0   21.47585697  -80.40897662
# 3               1  DZA  12         1   2.678164227   28.15940032
# 4               1  ASM  16         0  -170.7187269  -14.30587306
# 5               1  AND  20         1   1.576257417   42.54548611
# 6               1  AGO  24         1   17.57817062  -12.33724746
# 7               1  ATG  28         1   -61.7999755   17.07761471
# 8               1  AZE  31         1   50.01064725   40.39229544
# 9               1  ARG  32         1  -65.14563274  -35.19446255
#
#               areaName
# 0          Afghanistan
# 1              Albania
# 2           Antarctica
# 3              Algeria
# 4       American Samoa
# 5              Andorra
# 6               Angola
# 7  Antigua and Barbuda
# 8           Azerbaijan
# 9            Argentina

# %% [markdown]
# #### Call the endpoint of the SDG API that provides the list of hierarchical groupings of geographic Areas:

# %%
def geoAreaTree():
    http = urllib3.PoolManager()
    response = http.request('GET', "https://unstats.un.org/SDGAPI/v1/sdg/GeoArea/Tree")
    responseData = json.loads(response.data.decode('UTF-8'))
    
    return responseData

# %% [markdown]
# Note: The geoAreaTree object has various "trees" in it.  We usually use the "World" tree; however, some economic and geographic groupings are only in other trees.

# %%
print(len(geoAreaTree()))
for t in geoAreaTree():
    print('root='+t['geoAreaName'])
# Out:
# 7
# root=World
# root=Least Developed Countries (LDC)
# root=Land Locked Developing Countries (LLDC)
# root=Small Island Developing States (SIDS)
# root=Developed Regions
# root=Developing Regions
# root=Custom groupings of data providers

# %% [markdown]
# #### Traverse a hierarchical tree of geographic areas and convert it to a parent-child hierarchy table:

# %%
def flatten(tree):
    
    global hierarchy
    
    hierarchy = []
    traverse.level = 1
    traverse(tree)
    
    return pd.DataFrame(hierarchy)

# %%
def traverse(tree, parentCode=None, parentName=None):
    
    # print(' ' * traverse.level + 'Level: ' + str(traverse.level) + ', ' + tree['type'] + ', ' + str(tree['geoAreaCode']) + '-' + tree['geoAreaName'] )
    
    d = {}
    
    d['level'] = traverse.level
    d['type'] = tree['type']
    d['parentCode'] = parentCode
    d['parentName'] = parentName
    d['geoAreaCode'] = str(tree['geoAreaCode'])
    d['geoAreaName'] = tree['geoAreaName']
    
    hierarchy.append(d)
        
    if tree['children']:
        for child in tree['children']:
            traverse.level += 1
            traverse(child, str(tree['geoAreaCode']), tree['geoAreaName'])
            traverse.level -= 1
    
    return pd.DataFrame(hierarchy)

# %% [markdown]
# #### `geoAreas` holds the flattened list of geographic areas under 'World':

# %%
geoAreas = flatten(geoAreaTree()[0])
geoAreas.head()
print('...')
geoAreas.tail()
# Out:
#   geoAreaCode      geoAreaName  level parentCode       parentName     type
# 0           1            World      1       None             None   Region
# 1          10       Antarctica      2          1            World  Country
# 2           2           Africa      2          1            World   Region
# 3          15  Northern Africa      3          2           Africa   Region
# 4          12          Algeria      4         15  Northern Africa  Country
# ...
#     geoAreaCode                               geoAreaName  level parentCode  \
# 291         543  Oceania (exc. Australia and New Zealand)      3          9
# 292          62                 Central and Southern Asia      2          1
# 293         513               Europe and Northern America      2          1
# 294         747          Northern Africa and Western Asia      2          1
# 295         753            Eastern and South-Eastern Asia      2          1
#
#     parentName    type
# 291    Oceania  Region
# 292      World  Region
# 293      World  Region
# 294      World  Region
# 295      World  Region

# %% [markdown]
# ##### Temporary Fix for missing regions:

# %%
if('910' not in geoAreas['geoAreaCode']):
    d_910 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '910',
              'geoAreaName' : 'High income economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_910.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('911' not in geoAreas['geoAreaCode']):
    d_911 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '911',
              'geoAreaName' : 'Low income economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_911.items()})
    geoAreas = geoAreas.append(x, sort = True)

    
if('912' not in geoAreas['geoAreaCode']):
    d_912 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '912',
              'geoAreaName' : 'Lower middle economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_912.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('913' not in geoAreas['geoAreaCode']):
    d_913 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '913',
              'geoAreaName' : 'Low and middle income economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_913.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('914' not in geoAreas['geoAreaCode']):
    d_914 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '914',
              'geoAreaName' : 'Upper middle economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_914.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('135' not in geoAreas['geoAreaCode']):
    d_135 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '135',
              'geoAreaName' : 'Caucasus and Central Asia'
            }
    x = pd.DataFrame({k: [v] for k, v in d_135.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('127' not in geoAreas['geoAreaCode']):
    d_127 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '127',
              'geoAreaName' : 'Southern Asia (excluding India)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_127.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('199' not in geoAreas['geoAreaCode']):
    d_199 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '199',
              'geoAreaName' : 'Least Developed Countries (LDC)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_199.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('485' not in geoAreas['geoAreaCode']):
    d_485 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '485',
              'geoAreaName' : 'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_485.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('514' not in geoAreas['geoAreaCode']):
    d_514 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '514',
              'geoAreaName' : 'Developed Regions'
            }
    x = pd.DataFrame({k: [v] for k, v in d_514.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('515' not in geoAreas['geoAreaCode']):
    d_515 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '515',
              'geoAreaName' : 'Developing Regions'
            }
    x = pd.DataFrame({k: [v] for k, v in d_515.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('518' not in geoAreas['geoAreaCode']):
    d_518 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '518',
              'geoAreaName' : 'Eastern Asia (excluding Japan)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_518.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('738' not in geoAreas['geoAreaCode']):
    d_738 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '738',
              'geoAreaName' : 'Sub-Saharan Africa (inc. Sudan)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_738.items()})
    geoAreas = geoAreas.append(x, sort = True)

                 
if('746' not in geoAreas['geoAreaCode']):
    d_746 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '746',
              'geoAreaName' : 'Northern Africa (exc. Sudan)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_746.items()})
    geoAreas = geoAreas.append(x, sort = True)

#==================================

geoAreas = geoAreas.reset_index(drop=True)

geoAreas.tail(20)
# Out:
#     geoAreaCode                                        geoAreaName  level  \
# 290         876                          Wallis and Futuna Islands      4
# 291         543           Oceania (exc. Australia and New Zealand)      3
# 292          62                          Central and Southern Asia      2
# 293         513                        Europe and Northern America      2
# 294         747                   Northern Africa and Western Asia      2
# 295         753                     Eastern and South-Eastern Asia      2
# 296         910                         High income economies (WB)      1
# 297         911                          Low income economies (WB)      1
# 298         912                        Lower middle economies (WB)      1
# 299         913               Low and middle income economies (WB)      1
# 300         914                        Upper middle economies (WB)      1
# 301         135                          Caucasus and Central Asia      1
# 302         127                    Southern Asia (excluding India)      1
# 303         199                    Least Developed Countries (LDC)      1
# 304         485  Western Asia (exc. Armenia, Azerbaijan, Cyprus...      1
# 305         514                                  Developed Regions      1
# 306         515                                 Developing Regions      1
# 307         518                     Eastern Asia (excluding Japan)      1
# 308         738                    Sub-Saharan Africa (inc. Sudan)      1
# 309         746                       Northern Africa (exc. Sudan)      1
#
#     parentCode parentName     type
# 290         61  Polynesia  Country
# 291          9    Oceania   Region
# 292          1      World   Region
# 293          1      World   Region
# 294          1      World   Region
# 295          1      World   Region
# 296       None       None    Group
# 297       None       None    Group
# 298       None       None    Group
# 299       None       None    Group
# 300       None       None    Group
# 301       None       None    Group
# 302       None       None    Group
# 303       None       None    Group
# 304       None       None    Group
# 305       None       None    Group
# 306       None       None    Group
# 307       None       None    Group
# 308       None       None    Group
# 309       None       None    Group

# %% [markdown]
# #### Merge coordinates and list of geographic areas in SDG database

# %%
geoAreas_dict = geoAreas.to_dict('records')
geoAreas_dict[0]
# Out:
# {'geoAreaCode': '1',
#  'geoAreaName': 'World',
#  'level': 1,
#  'parentCode': None,
#  'parentName': None,
#  'type': 'Region'}

# %%
def geoareasXY(geoareas,coordinates_file):
    
    xy = countryListXY(coordinates_file)
    
    x = pd.merge(geoareas,xy.loc[:, xy.columns != 'geoAreaName'],
         how='outer',
         left_on='geoAreaCode', right_on='M49')
    x['order'] = x['geoAreaCode']
    x['order'] = x['order'].astype(float)
    x = x.sort_values('order')
    del x['order']
    del x['M49']
    
    x = x.reset_index(drop=True)
    
    x = x.to_dict('records')
    
    
    x_clean = []
    
    for i in x:
        i['geoAreaCode'] = i['geoAreaCode'].zfill(3)
        if i['parentCode']:
            i['parentCode'] = i['parentCode'].zfill(3)
        x_clean.append({k: None if str(v) == 'nan' else v for k, v in i.items()})
    
    
    
    return(x_clean)

# x.to_excel('test.xlsx', engine ='xlsxwriter')

# %%
geoareasXY(geoAreas, wd_dir + 'globalResources/refAreas.txt')[0:3]
# Out:
# [{'geoAreaCode': '001',
#   'geoAreaName': 'World',
#   'level': 1,
#   'parentCode': None,
#   'parentName': None,
#   'type': 'Region',
#   'Country_Profile': None,
#   'ISO3': None,
#   'UN_Member': None,
#   'X': None,
#   'Y': None,
#   'areaName': None},
#  {'geoAreaCode': '002',
#   'geoAreaName': 'Africa',
#   'level': 2,
#   'parentCode': '001',
#   'parentName': 'World',
#   'type': 'Region',
#   'Country_Profile': None,
#   'ISO3': None,
#   'UN_Member': None,
#   'X': None,
#   'Y': None,
#   'areaName': None},
#  {'geoAreaCode': '004',
#   'geoAreaName': 'Afghanistan',
#   'level': 4,
#   'parentCode': '034',
#   'parentName': 'Southern Asia',
#   'type': 'Country',
#   'Country_Profile': '1',
#   'ISO3': 'AFG',
#   'UN_Member': '1',
#   'X': '66.02688198',
#   'Y': '33.83160199',
#   'areaName': 'Afghanistan'}]

# %% [markdown]
# ### Get the list of goals, targets, indicators and series

# %%
with open(wd_dir + 'globalResources/metadata.json') as json_file:  
    metadata = json.load(json_file)

# %%
metadata[0]['targets'][0]['indicators'][0]['series'][0]
# Out:
# {'code': 'SI_POV_DAY1',
#  'description': 'Proportion of population below international poverty line (%)',
#  'release': '2019.Q1.G.03',
#  'tags': ['poverty line', 'poverty', 'standard of living', 'basic needs']}

# %% [markdown]
# #### Get list of unique data series

# %%
series = []
for g in metadata:
    for t in g['targets']:
        for i in t['indicators']:
            if 'series' in i.keys():
                for s in i['series']:
                    series.append(s['code'])
series = list(set(series))

series[0:10]
# Out:
# ['SG_NHR_INTEXST',
#  'SI_COV_PENSN',
#  'SG_PLN_MSTKSDG',
#  'EN_WWT_WWDS',
#  'SG_REG_BRTH90',
#  'DC_TOF_TRDCML',
#  'SH_STA_MMR',
#  'ER_WAT_PROCED',
#  'SH_STA_STUNT',
#  'SG_DSR_SILN']

# %% [markdown]
# ### Get the data for each series

# %% [markdown]
# #### Verify how many pages need to be requested to get all the data for a specific series from the SDG API.

# %%
def series_request_details(seriesCode,release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2"
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    pageSize = 500
    nPages = math.floor(responseData['totalElements'] / pageSize) + 1
    totalElements = responseData['totalElements']
    
    return {'series' : seriesCode,
            'totalElements' : totalElements,
            'nPages' : nPages, 
            'pageSize' : pageSize
           }

# %%
series_request_details('SL_EMP_INJUR', '2019.Q1.G.03')
# Out:
# {'series': 'SL_EMP_INJUR', 'totalElements': 3353, 'nPages': 7, 'pageSize': 500}

# %% [markdown]
# #### Explore the code lists of the attributes and dimensions of a series
# Describe each attribute or dimension as a simple dictionary made of a set of `code`-`description` pairs.  For the code, use the SDMX code, and not the internal codeof the database.  Keep all labels in camelCase.

# %%
def series_code_lists(seriesCode, release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2"
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    series_attributes = responseData['attributes']
    series_dimensions = responseData['dimensions']
    
    new_dict = {}
    
    new_dict['seriesCode'] = seriesCode
    
    for a in series_attributes:
        codelist_dict = {}
        for c in a['codes']:
            codelist_dict[c['code']] = c['description']
        new_dict[camelCase(a['id'])] = codelist_dict
    
    for d in series_dimensions:
        codelist_dict = {}
        for c in d['codes']:
            codelist_dict[c['code']] = c['description']
        new_dict[camelCase(d['id'])] = codelist_dict
        
    return new_dict

# %%
series_code_lists('SL_EMP_INJUR', '2019.Q1.G.03')
# Out:
# {'seriesCode': 'SL_EMP_INJUR',
#  'nature': {'C': 'Country data',
#   'CA': 'Country adjusted data',
#   'E': 'Estimated data',
#   'G': 'Global monitoring data',
#   'M': 'Modeled data',
#   'N': 'Non-relevant',
#   'NA': 'Data nature not available'},
#  'units': {'PER_100000_EMP': 'Per 100,000 employees',
#   'PER_100000_PRSN_INSR': 'Per 100,000 persons insured',
#   'PER_100000_WKRS_EMP': 'Per 100,000 workers employed'},
#  'migratoryStatus': {'_T': 'No breakdown',
#   'MIGPER': 'Migrants',
#   'NONMIG': 'Non-migrant',
#   'EUMIG': 'EU Migrants',
#   'NONEUMIG': 'Non-EU Migrants'},
#  'reportingType': {'N': 'National', 'G': 'Global'},
#  'sex': {'FEMALE': 'Female', 'MALE': 'Male', 'BOTHSEX': 'Both sexes'}}

# %% [markdown]
# #### Simplify further by presenting all the codes and their descriptions in a single table:

# %%
def series_code_lists2(seriesCode, release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2" 
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    series_attributes = responseData['attributes']
    series_dimensions = responseData['dimensions']
    
    code_list = []
    
    for a in series_attributes:
       
        for c in a['codes']:
            new_dict = {}
            new_dict['series'] = seriesCode
            new_dict['role'] = 'attribute'
            new_dict['concept'] = camelCase(a['id'])
            new_dict['code'] = c['code']
            new_dict['sdmx'] = c['sdmx']
            new_dict['description'] = c['description']
            code_list.append(new_dict)
        
    for d in series_dimensions:
        for c in d['codes']:
            new_dict = {}
            new_dict['series'] = seriesCode
            new_dict['role'] = 'dimension'
            new_dict['concept'] = camelCase(d['id'])
            new_dict['code'] = c['code']
            new_dict['sdmx'] = c['sdmx']
            new_dict['description'] = c['description']
            code_list.append(new_dict)
        
    return pd.DataFrame(code_list)

# %%
def series_code_lists3(seriesCode, release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2" 
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    series_attributes = responseData['attributes']
    series_dimensions = responseData['dimensions']
    
    concepts = []
    
    for d in series_dimensions:

        new_dict = {}
        new_dict['concept'] = camelCase(d['id'])
        new_dict['role'] = 'dimension'
        new_dict['codes'] = []
        for c in d['codes']:
            new_dict2 = {}
            new_dict2['code'] = c['code']
            new_dict2['sdmx'] = c['sdmx']
            new_dict2['description'] = c['description']
            new_dict['codes'].append(new_dict2)
        concepts.append(new_dict)
    
    for a in series_attributes:
        
        new_dict = {}
        new_dict['concept'] = camelCase(a['id'])
        new_dict['role'] = 'attribute'
        new_dict['codes'] = []
        for c in a['codes']:
            new_dict2 = {}
            new_dict2['code'] = c['code']
            new_dict2['sdmx'] = c['sdmx']
            new_dict2['description'] = c['description']
            new_dict['codes'].append(new_dict2)
        concepts.append(new_dict)
        
        
    return concepts #pd.DataFrame(code_list)

# %%
series_code_lists2('SL_EMP_INJUR', '2019.Q1.G.03')
series_code_lists3('SL_EMP_INJUR', '2019.Q1.G.03')
# Out:
#                     code          concept                   description  \
# 0                      C           nature                  Country data
# 1                     CA           nature         Country adjusted data
# 2                      E           nature                Estimated data
# 3                      G           nature        Global monitoring data
# 4                      M           nature                  Modeled data
# 5                      N           nature                  Non-relevant
# 6                     NA           nature     Data nature not available
# 7         PER_100000_EMP            units         Per 100,000 employees
# 8   PER_100000_PRSN_INSR            units   Per 100,000 persons insured
# 9    PER_100000_WKRS_EMP            units  Per 100,000 workers employed
# 10                    _T  migratoryStatus                  No breakdown
# 11                MIGPER  migratoryStatus                      Migrants
# 12                NONMIG  migratoryStatus                   Non-migrant
# 13                 EUMIG  migratoryStatus                   EU Migrants
# 14              NONEUMIG  migratoryStatus               Non-EU Migrants
# 15                     N    reportingType                      National
# 16                     G    reportingType                        Global
# 17                FEMALE              sex                        Female
# 18                  MALE              sex                          Male
# 19               BOTHSEX              sex                    Both sexes
#
#          role                  sdmx        series
# 0   attribute                     C  SL_EMP_INJUR
# 1   attribute                    CA  SL_EMP_INJUR
# 2   attribute                     E  SL_EMP_INJUR
# 3   attribute                     G  SL_EMP_INJUR
# 4   attribute                     M  SL_EMP_INJUR
# 5   attribute                     N  SL_EMP_INJUR
# 6   attribute                    NA  SL_EMP_INJUR
# 7   attribute        PER_100000_EMP  SL_EMP_INJUR
# 8   attribute  PER_100000_PRSN_INSR  SL_EMP_INJUR
# 9   attribute   PER_100000_WKRS_EMP  SL_EMP_INJUR
# 10  dimension                    _T  SL_EMP_INJUR
# 11  dimension                MIGPER  SL_EMP_INJUR
# 12  dimension                NONMIG  SL_EMP_INJUR
# 13  dimension          MS_EUMIGRANT  SL_EMP_INJUR
# 14  dimension       MS_NONEUMIGRANT  SL_EMP_INJUR
# 15  dimension                     N  SL_EMP_INJUR
# 16  dimension                     G  SL_EMP_INJUR
# 17  dimension                     F  SL_EMP_INJUR
# 18  dimension                     M  SL_EMP_INJUR
# 19  dimension                    _T  SL_EMP_INJUR
# [{'concept': 'migratoryStatus',
#   'role': 'dimension',
#   'codes': [{'code': '_T', 'sdmx': '_T', 'description': 'No breakdown'},
#    {'code': 'MIGPER', 'sdmx': 'MIGPER', 'description': 'Migrants'},
#    {'code': 'NONMIG', 'sdmx': 'NONMIG', 'description': 'Non-migrant'},
#    {'code': 'EUMIG', 'sdmx': 'MS_EUMIGRANT', 'description': 'EU Migrants'},
#    {'code': 'NONEUMIG',
#     'sdmx': 'MS_NONEUMIGRANT',
#     'description': 'Non-EU Migrants'}]},
#  {'concept': 'reportingType',
#   'role': 'dimension',
#   'codes': [{'code': 'N', 'sdmx': 'N', 'description': 'National'},
#    {'code': 'G', 'sdmx': 'G', 'description': 'Global'}]},
#  {'concept': 'sex',
#   'role': 'dimension',
#   'codes': [{'code': 'FEMALE', 'sdmx': 'F', 'description': 'Female'},
#    {'code': 'MALE', 'sdmx': 'M', 'description': 'Male'},
#    {'code': 'BOTHSEX', 'sdmx': '_T', 'description': 'Both sexes'}]},
#  {'concept': 'nature',
#   'role': 'attribute',
#   'codes': [{'code': 'C', 'sdmx': 'C', 'description': 'Country data'},
#    {'code': 'CA', 'sdmx': 'CA', 'description': 'Country adjusted data'},
#    {'code': 'E', 'sdmx': 'E', 'description': 'Estimated data'},
#    {'code': 'G', 'sdmx': 'G', 'description': 'Global monitoring data'},
#    {'code': 'M', 'sdmx': 'M', 'description': 'Modeled data'},
#    {'code': 'N', 'sdmx': 'N', 'description': 'Non-relevant'},
#    {'code': 'NA', 'sdmx': 'NA', 'description': 'Data nature not available'}]},
#  {'concept': 'units',
#   'role': 'attribute',
#   'codes': [{'code': 'PER_100000_EMP',
#     'sdmx': 'PER_100000_EMP',
#     'description': 'Per 100,000 employees'},
#    {'code': 'PER_100000_PRSN_INSR',
#     'sdmx': 'PER_100000_PRSN_INSR',
#     'description': 'Per 100,000 persons insured'},
#    {'code': 'PER_100000_WKRS_EMP',
#     'sdmx': 'PER_100000_WKRS_EMP',
#     'description': 'Per 100,000 workers employed'}]}]

# %% [markdown]
# #### Build query string to collect data for a specific series from the global SDG API

# %%
def series_query(seriesCode, release, page, pageSize):
    queryString =  r'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + '&page=' + str(page) + '&pageSize=' + str(pageSize)
    http = urllib3.PoolManager()
    response = http.request('GET', queryString)
    responseData =  json.loads(response.data.decode('UTF-8'))
    return(responseData)

# %% [markdown]
# #### Get data for a specific series from the API
# *(!) Notice that a data point may appear more than once if it belongs to a "multi-purpose indicator"*

# %%
def series_data(seriesCode, release):
    x = series_request_details(seriesCode,release)
    series_data = []
    if x['totalElements'] > 0:
        for p in range(x['nPages']):
            print("---Series " + seriesCode + ": Processing page " + str(p+1) + " of " + str(x['nPages']))
            responseData =  series_query(seriesCode, release, p+1, x['pageSize'])
            if len(responseData['data'])>0:
                series_data = series_data + responseData['data'] 
    return series_data

# %%
x = series_data('SL_EMP_INJUR','2019.Q1.G.03')
if len(x) > 0:
    x[0]
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 7
# ---Series SL_EMP_INJUR: Processing page 2 of 7
# ---Series SL_EMP_INJUR: Processing page 3 of 7
# ---Series SL_EMP_INJUR: Processing page 4 of 7
# ---Series SL_EMP_INJUR: Processing page 5 of 7
# ---Series SL_EMP_INJUR: Processing page 6 of 7
# ---Series SL_EMP_INJUR: Processing page 7 of 7
# {'goal': ['8'],
#  'target': ['8.8'],
#  'indicator': ['8.8.1'],
#  'series': 'SL_EMP_INJUR',
#  'seriesDescription': 'Non-fatal occupational injuries among employees, by sex and migrant status (per 100,000 employees)',
#  'seriesCount': '3353',
#  'geoAreaCode': '12',
#  'geoAreaName': 'Algeria',
#  'timePeriodStart': 2000.0,
#  'value': '1541.5',
#  'valueType': 'Float',
#  'time_detail': None,
#  'source': 'ILOSTAT - ADM-IR - Insurance records',
#  'footnotes': ['Coverage of occupational injuries: Compensated injuries | Reference group coverage: Insured persons'],
#  'attributes': {'Nature': 'C', 'Units': 'PER_100000_EMP'},
#  'dimensions': {'Sex': 'BOTHSEX',
#   'Migratory status': '_T',
#   'Reporting Type': 'G'}}

# %% [markdown]
# #### Flatten the dictionary, extracting individual attributes and dimensions as key-value pairs in their own right.
# Also convert the years (`timePeriod`) variable to `int`

# %%
geo = geoareasXY(geoAreas, wd_dir + 'globalResources/refAreas.txt')
geo[0]
# Out:
# {'geoAreaCode': '001',
#  'geoAreaName': 'World',
#  'level': 1,
#  'parentCode': None,
#  'parentName': None,
#  'type': 'Region',
#  'Country_Profile': None,
#  'ISO3': None,
#  'UN_Member': None,
#  'X': None,
#  'Y': None,
#  'areaName': None}

# %%
def flat_series_data(seriesCode,release):

    codeLists = series_code_lists3(seriesCode,release)
    
    new_x = []
    for d in series_data(seriesCode,release):
        new_d = {}
        for key, value in d.items():
            if type(value) is list:
                new_d[key] = ', '.join(value)
            elif type(value) is dict:
                for k, v in value.items():
                    new_d[camelCase(k+' Code')] = v
                    for cl in codeLists:
                        if cl['concept'] == camelCase(k):
                            for c in cl['codes']:
                                if c['code'] == v:
                                    new_d[camelCase(k+' Desc')] = c['description']
                                    new_d[camelCase(k+' Code')] = c['sdmx']
                                    break
                            break
            elif key == 'time_detail':
                new_d[camelCase(key)] = value
            elif key == 'timePeriodStart':
                new_d['timePeriod'] = int(value)
            elif key == 'series':
                new_d['seriesCode'] = value
            elif key == 'seriesDescription':
                new_d['seriesDesc'] = value
            elif key == 'geoAreaCode':
                new_d['geoAreaCode'] = str(value).zfill(3)
            else:
                new_d[key] = value

        new_d['value_numeric_part'] = numeric_part(new_d['value'])
        new_d['value_is_censored'] = (new_d['valueType'] != 'Float')
        new_d['value_detail'] = new_d['value']

        del new_d['value']
        del new_d['valueType']
        del new_d['seriesCount']

        new_x.append(new_d)

    return new_x

# %%
x = flat_series_data('SL_EMP_INJUR','2019.Q1.G.03')
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 7
# ---Series SL_EMP_INJUR: Processing page 2 of 7
# ---Series SL_EMP_INJUR: Processing page 3 of 7
# ---Series SL_EMP_INJUR: Processing page 4 of 7
# ---Series SL_EMP_INJUR: Processing page 5 of 7
# ---Series SL_EMP_INJUR: Processing page 6 of 7
# ---Series SL_EMP_INJUR: Processing page 7 of 7

# %%
x[0]
# Out:
# {'goal': '8',
#  'target': '8.8',
#  'indicator': '8.8.1',
#  'seriesCode': 'SL_EMP_INJUR',
#  'seriesDesc': 'Non-fatal occupational injuries among employees, by sex and migrant status (per 100,000 employees)',
#  'geoAreaCode': '012',
#  'geoAreaName': 'Algeria',
#  'timePeriod': 2000,
#  'timeDetail': None,
#  'source': 'ILOSTAT - ADM-IR - Insurance records',
#  'footnotes': 'Coverage of occupational injuries: Compensated injuries | Reference group coverage: Insured persons',
#  'natureCode': 'C',
#  'natureDesc': 'Country data',
#  'unitsCode': 'PER_100000_EMP',
#  'unitsDesc': 'Per 100,000 employees',
#  'sexCode': '_T',
#  'sexDesc': 'Both sexes',
#  'migratoryStatusCode': '_T',
#  'migratoryStatusDesc': 'No breakdown',
#  'reportingTypeCode': 'G',
#  'reportingTypeDesc': 'Global',
#  'value_numeric_part': 1541.5,
#  'value_is_censored': False,
#  'value_detail': '1541.5'}

# %% [markdown]
# ##### Select distinct indicator-series that are included in the dataset
#
# When there is a 'multi-purpose indicator', the same data series is part of two different goal-target-indicator specification.

# %%
indicator_series = unique_dicts(subdict_list(x,['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc'])
)

# %% [markdown]
# Now, for each `indicator_series`, we want to build a json file that contains all the necessary information to be published as a layer. This requires to build a tree structure with the following levels:
# - Information about the goal, target, indicator, and series
# - Information about the geographic reference area
# - Data grouped by time period

# %%
series = 'SL_EMP_INJUR'
release = '2019.Q1.G.03'

x = flat_series_data(series,release)

indicator_series =  unique_dicts(subdict_list(x,['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc'])
)
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 7
# ---Series SL_EMP_INJUR: Processing page 2 of 7
# ---Series SL_EMP_INJUR: Processing page 3 of 7
# ---Series SL_EMP_INJUR: Processing page 4 of 7
# ---Series SL_EMP_INJUR: Processing page 5 of 7
# ---Series SL_EMP_INJUR: Processing page 6 of 7
# ---Series SL_EMP_INJUR: Processing page 7 of 7

# %%
x[0]
geo[0]
# Out:
# {'goal': '8',
#  'target': '8.8',
#  'indicator': '8.8.1',
#  'seriesCode': 'SL_EMP_INJUR',
#  'seriesDesc': 'Non-fatal occupational injuries among employees, by sex and migrant status (per 100,000 employees)',
#  'geoAreaCode': '012',
#  'geoAreaName': 'Algeria',
#  'timePeriod': 2000,
#  'timeDetail': None,
#  'source': 'ILOSTAT - ADM-IR - Insurance records',
#  'footnotes': 'Coverage of occupational injuries: Compensated injuries | Reference group coverage: Insured persons',
#  'natureCode': 'C',
#  'natureDesc': 'Country data',
#  'unitsCode': 'PER_100000_EMP',
#  'unitsDesc': 'Per 100,000 employees',
#  'sexCode': '_T',
#  'sexDesc': 'Both sexes',
#  'migratoryStatusCode': '_T',
#  'migratoryStatusDesc': 'No breakdown',
#  'reportingTypeCode': 'G',
#  'reportingTypeDesc': 'Global',
#  'value_numeric_part': 1541.5,
#  'value_is_censored': False,
#  'value_detail': '1541.5'}
# {'geoAreaCode': '001',
#  'geoAreaName': 'World',
#  'level': 1,
#  'parentCode': None,
#  'parentName': None,
#  'type': 'Region',
#  'Country_Profile': None,
#  'ISO3': None,
#  'UN_Member': None,
#  'X': None,
#  'Y': None,
#  'areaName': None}

# %%
def get_data_to_json(series, release):
    
    x = flat_series_data(series,release)

    indicator_series =  unique_dicts(subdict_list(x,['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc'])
    )

    dataset = []
    for s in indicator_series:
        d = s.copy()
        d['release'] = release
        indicator = d['indicator']
        data = select_dict(x, 'indicator', indicator)
        d['refAreas'] = geo.copy()
        for g in d['refAreas']:
            g_data = subdict_list(select_dict(data, 'geoAreaCode', g['geoAreaCode']),
                                  ['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc','geoAreaCode', 'geoAreaName'], 
                                  exclude = True)
            g['data'] = g_data

        file_name = release + '\Indicator_' + indicator + '_Series_' + d['seriesCode'] + '.json'

        with open(wd_dir + r'data\unsd\\' + file_name, 'w') as f:
            json.dump(d, f, indent=4)
        
        print('created file ' + file_name)

# %%
get_data_to_json(series = 'SL_EMP_INJUR', release = '2019.Q1.G.03')
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 7
# ---Series SL_EMP_INJUR: Processing page 2 of 7
# ---Series SL_EMP_INJUR: Processing page 3 of 7
# ---Series SL_EMP_INJUR: Processing page 4 of 7
# ---Series SL_EMP_INJUR: Processing page 5 of 7
# ---Series SL_EMP_INJUR: Processing page 6 of 7
# ---Series SL_EMP_INJUR: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_8.8.1_Series_SL_EMP_INJUR.json

# %% [markdown]
# #### Produce 'long' files for each indicator/series combination
# (Notice that multi-purpose indicators need to be split)

# %%
series = []
for g in metadata:
    for t in g['targets']:
        for i in t['indicators']:
            if 'series' in i.keys():
                for s in i['series']:
                    series.append(s['code'])
series = list(set(series))

for s in series:
    get_data_to_json(series = s, release = '2019.Q1.G.03')
# Out:
# ---Series SG_NHR_INTEXST: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_16.a.1_Series_SG_NHR_INTEXST.json
# ---Series SI_COV_PENSN: Processing page 1 of 2
# ---Series SI_COV_PENSN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_PENSN.json
# ---Series SG_PLN_MSTKSDG: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.16.1_Series_SG_PLN_MSTKSDG.json
# ---Series EN_WWT_WWDS: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.3.1_Series_EN_WWT_WWDS.json
# ---Series SG_REG_BRTH90: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.19.2_Series_SG_REG_BRTH90.json
# ---Series DC_TOF_TRDCML: Processing page 1 of 4
# ---Series DC_TOF_TRDCML: Processing page 2 of 4
# ---Series DC_TOF_TRDCML: Processing page 3 of 4
# ---Series DC_TOF_TRDCML: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_8.a.1_Series_DC_TOF_TRDCML.json
# ---Series SH_STA_MMR: Processing page 1 of 35
# ---Series SH_STA_MMR: Processing page 2 of 35
# ---Series SH_STA_MMR: Processing page 3 of 35
# ---Series SH_STA_MMR: Processing page 4 of 35
# ---Series SH_STA_MMR: Processing page 5 of 35
# ---Series SH_STA_MMR: Processing page 6 of 35
# ---Series SH_STA_MMR: Processing page 7 of 35
# ---Series SH_STA_MMR: Processing page 8 of 35
# ---Series SH_STA_MMR: Processing page 9 of 35
# ---Series SH_STA_MMR: Processing page 10 of 35
# ---Series SH_STA_MMR: Processing page 11 of 35
# ---Series SH_STA_MMR: Processing page 12 of 35
# ---Series SH_STA_MMR: Processing page 13 of 35
# ---Series SH_STA_MMR: Processing page 14 of 35
# ---Series SH_STA_MMR: Processing page 15 of 35
# ---Series SH_STA_MMR: Processing page 16 of 35
# ---Series SH_STA_MMR: Processing page 17 of 35
# ---Series SH_STA_MMR: Processing page 18 of 35
# ---Series SH_STA_MMR: Processing page 19 of 35
# ---Series SH_STA_MMR: Processing page 20 of 35
# ---Series SH_STA_MMR: Processing page 21 of 35
# ---Series SH_STA_MMR: Processing page 22 of 35
# ---Series SH_STA_MMR: Processing page 23 of 35
# ---Series SH_STA_MMR: Processing page 24 of 35
# ---Series SH_STA_MMR: Processing page 25 of 35
# ---Series SH_STA_MMR: Processing page 26 of 35
# ---Series SH_STA_MMR: Processing page 27 of 35
# ---Series SH_STA_MMR: Processing page 28 of 35
# ---Series SH_STA_MMR: Processing page 29 of 35
# ---Series SH_STA_MMR: Processing page 30 of 35
# ---Series SH_STA_MMR: Processing page 31 of 35
# ---Series SH_STA_MMR: Processing page 32 of 35
# ---Series SH_STA_MMR: Processing page 33 of 35
# ---Series SH_STA_MMR: Processing page 34 of 35
# ---Series SH_STA_MMR: Processing page 35 of 35
# created file 2019.Q1.G.03\Indicator_3.1.1_Series_SH_STA_MMR.json
# ---Series ER_WAT_PROCED: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.b.1_Series_ER_WAT_PROCED.json
# ---Series SH_STA_STUNT: Processing page 1 of 2
# ---Series SH_STA_STUNT: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_2.2.1_Series_SH_STA_STUNT.json
# ---Series SG_DSR_SILN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.5.4_Series_SG_DSR_SILN.json
# created file 2019.Q1.G.03\Indicator_11.b.2_Series_SG_DSR_SILN.json
# created file 2019.Q1.G.03\Indicator_13.1.3_Series_SG_DSR_SILN.json
# ---Series ER_RSK_LBREDN: Processing page 1 of 12
# ---Series ER_RSK_LBREDN: Processing page 2 of 12
# ---Series ER_RSK_LBREDN: Processing page 3 of 12
# ---Series ER_RSK_LBREDN: Processing page 4 of 12
# ---Series ER_RSK_LBREDN: Processing page 5 of 12
# ---Series ER_RSK_LBREDN: Processing page 6 of 12
# ---Series ER_RSK_LBREDN: Processing page 7 of 12
# ---Series ER_RSK_LBREDN: Processing page 8 of 12
# ---Series ER_RSK_LBREDN: Processing page 9 of 12
# ---Series ER_RSK_LBREDN: Processing page 10 of 12
# ---Series ER_RSK_LBREDN: Processing page 11 of 12
# ---Series ER_RSK_LBREDN: Processing page 12 of 12
# created file 2019.Q1.G.03\Indicator_2.5.2_Series_ER_RSK_LBREDN.json
# ---Series SG_INT_MBRDEV: Processing page 1 of 29
# ---Series SG_INT_MBRDEV: Processing page 2 of 29
# ---Series SG_INT_MBRDEV: Processing page 3 of 29
# ---Series SG_INT_MBRDEV: Processing page 4 of 29
# ---Series SG_INT_MBRDEV: Processing page 5 of 29
# ---Series SG_INT_MBRDEV: Processing page 6 of 29
# ---Series SG_INT_MBRDEV: Processing page 7 of 29
# ---Series SG_INT_MBRDEV: Processing page 8 of 29
# ---Series SG_INT_MBRDEV: Processing page 9 of 29
# ---Series SG_INT_MBRDEV: Processing page 10 of 29
# ---Series SG_INT_MBRDEV: Processing page 11 of 29
# ---Series SG_INT_MBRDEV: Processing page 12 of 29
# ---Series SG_INT_MBRDEV: Processing page 13 of 29
# ---Series SG_INT_MBRDEV: Processing page 14 of 29
# ---Series SG_INT_MBRDEV: Processing page 15 of 29
# ---Series SG_INT_MBRDEV: Processing page 16 of 29
# ---Series SG_INT_MBRDEV: Processing page 17 of 29
# ---Series SG_INT_MBRDEV: Processing page 18 of 29
# ---Series SG_INT_MBRDEV: Processing page 19 of 29
# ---Series SG_INT_MBRDEV: Processing page 20 of 29
# ---Series SG_INT_MBRDEV: Processing page 21 of 29
# ---Series SG_INT_MBRDEV: Processing page 22 of 29
# ---Series SG_INT_MBRDEV: Processing page 23 of 29
# ---Series SG_INT_MBRDEV: Processing page 24 of 29
# ---Series SG_INT_MBRDEV: Processing page 25 of 29
# ---Series SG_INT_MBRDEV: Processing page 26 of 29
# ---Series SG_INT_MBRDEV: Processing page 27 of 29
# ---Series SG_INT_MBRDEV: Processing page 28 of 29
# ---Series SG_INT_MBRDEV: Processing page 29 of 29
# created file 2019.Q1.G.03\Indicator_10.6.1_Series_SG_INT_MBRDEV.json
# created file 2019.Q1.G.03\Indicator_16.8.1_Series_SG_INT_MBRDEV.json
# ---Series IS_RDP_PFVOL: Processing page 1 of 2
# ---Series IS_RDP_PFVOL: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_9.1.2_Series_IS_RDP_PFVOL.json
# ---Series SI_COV_SOCINS: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_SOCINS.json
# ---Series SG_NHR_IMPLN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_16.a.1_Series_SG_NHR_IMPLN.json
# ---Series SP_DYN_MRBF15: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_5.3.1_Series_SP_DYN_MRBF15.json
# ---Series SL_TLF_NEET: Processing page 1 of 9
# ---Series SL_TLF_NEET: Processing page 2 of 9
# ---Series SL_TLF_NEET: Processing page 3 of 9
# ---Series SL_TLF_NEET: Processing page 4 of 9
# ---Series SL_TLF_NEET: Processing page 5 of 9
# ---Series SL_TLF_NEET: Processing page 6 of 9
# ---Series SL_TLF_NEET: Processing page 7 of 9
# ---Series SL_TLF_NEET: Processing page 8 of 9
# ---Series SL_TLF_NEET: Processing page 9 of 9
# created file 2019.Q1.G.03\Indicator_8.6.1_Series_SL_TLF_NEET.json
# ---Series VC_DSR_CHLN: Processing page 1 of 4
# ---Series VC_DSR_CHLN: Processing page 2 of 4
# ---Series VC_DSR_CHLN: Processing page 3 of 4
# ---Series VC_DSR_CHLN: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_1.5.2_Series_VC_DSR_CHLN.json
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_CHLN.json
# ---Series AG_XPD_AGSGB: Processing page 1 of 11
# ---Series AG_XPD_AGSGB: Processing page 2 of 11
# ---Series AG_XPD_AGSGB: Processing page 3 of 11
# ---Series AG_XPD_AGSGB: Processing page 4 of 11
# ---Series AG_XPD_AGSGB: Processing page 5 of 11
# ---Series AG_XPD_AGSGB: Processing page 6 of 11
# ---Series AG_XPD_AGSGB: Processing page 7 of 11
# ---Series AG_XPD_AGSGB: Processing page 8 of 11
# ---Series AG_XPD_AGSGB: Processing page 9 of 11
# ---Series AG_XPD_AGSGB: Processing page 10 of 11
# ---Series AG_XPD_AGSGB: Processing page 11 of 11
# created file 2019.Q1.G.03\Indicator_2.a.1_Series_AG_XPD_AGSGB.json
# ---Series SI_HEI_BTN40: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_10.1.1_Series_SI_HEI_BTN40.json
# ---Series SH_SAN_DEFECT: Processing page 1 of 17
# ---Series SH_SAN_DEFECT: Processing page 2 of 17
# ---Series SH_SAN_DEFECT: Processing page 3 of 17
# ---Series SH_SAN_DEFECT: Processing page 4 of 17
# ---Series SH_SAN_DEFECT: Processing page 5 of 17
# ---Series SH_SAN_DEFECT: Processing page 6 of 17
# ---Series SH_SAN_DEFECT: Processing page 7 of 17
# ---Series SH_SAN_DEFECT: Processing page 8 of 17
# ---Series SH_SAN_DEFECT: Processing page 9 of 17
# ---Series SH_SAN_DEFECT: Processing page 10 of 17
# ---Series SH_SAN_DEFECT: Processing page 11 of 17
# ---Series SH_SAN_DEFECT: Processing page 12 of 17
# ---Series SH_SAN_DEFECT: Processing page 13 of 17
# ---Series SH_SAN_DEFECT: Processing page 14 of 17
# ---Series SH_SAN_DEFECT: Processing page 15 of 17
# ---Series SH_SAN_DEFECT: Processing page 16 of 17
# ---Series SH_SAN_DEFECT: Processing page 17 of 17
# created file 2019.Q1.G.03\Indicator_6.2.1_Series_SH_SAN_DEFECT.json
# ---Series SI_COV_UEMP: Processing page 1 of 2
# ---Series SI_COV_UEMP: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_UEMP.json
# ---Series SG_STT_NSDSFDGVT: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.18.3_Series_SG_STT_NSDSFDGVT.json
# ---Series ER_MRN_MARINT: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_14.5.1_Series_ER_MRN_MARINT.json
# ---Series SL_TLF_MANF: Processing page 1 of 5
# ---Series SL_TLF_MANF: Processing page 2 of 5
# ---Series SL_TLF_MANF: Processing page 3 of 5
# ---Series SL_TLF_MANF: Processing page 4 of 5
# ---Series SL_TLF_MANF: Processing page 5 of 5
# created file 2019.Q1.G.03\Indicator_9.2.2_Series_SL_TLF_MANF.json
# ---Series SG_REG_DETH75: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.19.2_Series_SG_REG_DETH75.json
# ---Series VC_DSR_MISS: Processing page 1 of 6
# ---Series VC_DSR_MISS: Processing page 2 of 6
# ---Series VC_DSR_MISS: Processing page 3 of 6
# ---Series VC_DSR_MISS: Processing page 4 of 6
# ---Series VC_DSR_MISS: Processing page 5 of 6
# ---Series VC_DSR_MISS: Processing page 6 of 6
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_MISS.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_MISS.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_MISS.json
# ---Series SH_AAP_ASMORT: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_3.9.1_Series_SH_AAP_ASMORT.json
# ---Series SG_HAZ_CMRMNTRL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_12.4.1_Series_SG_HAZ_CMRMNTRL.json
# ---Series EN_WBE_NDQLGRW: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.6.1_Series_EN_WBE_NDQLGRW.json
# ---Series SE_NAP_ACHIRE: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_4.5.1_Series_SE_NAP_ACHIRE.json
# ---Series ER_WAT_PART: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.b.1_Series_ER_WAT_PART.json
# ---Series SH_STA_AIRP: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_3.9.1_Series_SH_STA_AIRP.json
# ---Series SH_ACS_DTP3: Processing page 1 of 9
# ---Series SH_ACS_DTP3: Processing page 2 of 9
# ---Series SH_ACS_DTP3: Processing page 3 of 9
# ---Series SH_ACS_DTP3: Processing page 4 of 9
# ---Series SH_ACS_DTP3: Processing page 5 of 9
# ---Series SH_ACS_DTP3: Processing page 6 of 9
# ---Series SH_ACS_DTP3: Processing page 7 of 9
# ---Series SH_ACS_DTP3: Processing page 8 of 9
# ---Series SH_ACS_DTP3: Processing page 9 of 9
# created file 2019.Q1.G.03\Indicator_3.b.1_Series_SH_ACS_DTP3.json
# ---Series AG_PRD_FIESSIN: Processing page 1 of 3
# ---Series AG_PRD_FIESSIN: Processing page 2 of 3
# ---Series AG_PRD_FIESSIN: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_2.1.2_Series_AG_PRD_FIESSIN.json
# ---Series VC_DSR_HSDN: Processing page 1 of 2
# ---Series VC_DSR_HSDN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_HSDN.json
# ---Series SE_SEP_MATACH: Processing page 1 of 2
# ---Series SE_SEP_MATACH: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_4.5.1_Series_SE_SEP_MATACH.json
# ---Series SH_STA_WASTEN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_2.2.2_Series_SH_STA_WASTEN.json
# ---Series EN_H2O_RVAMBQ: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.3.2_Series_EN_H2O_RVAMBQ.json
# ---Series AG_PRD_AGVAS: Processing page 1 of 11
# ---Series AG_PRD_AGVAS: Processing page 2 of 11
# ---Series AG_PRD_AGVAS: Processing page 3 of 11
# ---Series AG_PRD_AGVAS: Processing page 4 of 11
# ---Series AG_PRD_AGVAS: Processing page 5 of 11
# ---Series AG_PRD_AGVAS: Processing page 6 of 11
# ---Series AG_PRD_AGVAS: Processing page 7 of 11
# ---Series AG_PRD_AGVAS: Processing page 8 of 11
# ---Series AG_PRD_AGVAS: Processing page 9 of 11
# ---Series AG_PRD_AGVAS: Processing page 10 of 11
# ---Series AG_PRD_AGVAS: Processing page 11 of 11
# created file 2019.Q1.G.03\Indicator_2.a.1_Series_AG_PRD_AGVAS.json
# ---Series SI_POV_EMP1: Processing page 1 of 19
# ---Series SI_POV_EMP1: Processing page 2 of 19
# ---Series SI_POV_EMP1: Processing page 3 of 19
# ---Series SI_POV_EMP1: Processing page 4 of 19
# ---Series SI_POV_EMP1: Processing page 5 of 19
# ---Series SI_POV_EMP1: Processing page 6 of 19
# ---Series SI_POV_EMP1: Processing page 7 of 19
# ---Series SI_POV_EMP1: Processing page 8 of 19
# ---Series SI_POV_EMP1: Processing page 9 of 19
# ---Series SI_POV_EMP1: Processing page 10 of 19
# ---Series SI_POV_EMP1: Processing page 11 of 19
# ---Series SI_POV_EMP1: Processing page 12 of 19
# ---Series SI_POV_EMP1: Processing page 13 of 19
# ---Series SI_POV_EMP1: Processing page 14 of 19
# ---Series SI_POV_EMP1: Processing page 15 of 19
# ---Series SI_POV_EMP1: Processing page 16 of 19
# ---Series SI_POV_EMP1: Processing page 17 of 19
# ---Series SI_POV_EMP1: Processing page 18 of 19
# ---Series SI_POV_EMP1: Processing page 19 of 19
# created file 2019.Q1.G.03\Indicator_1.1.1_Series_SI_POV_EMP1.json
# ---Series DC_ODA_SIDS: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.2.1_Series_DC_ODA_SIDS.json
# ---Series VC_DSR_OBDN: Processing page 1 of 2
# ---Series VC_DSR_OBDN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_OBDN.json
# ---Series SE_GPI_TRATEA: Processing page 1 of 5
# ---Series SE_GPI_TRATEA: Processing page 2 of 5
# ---Series SE_GPI_TRATEA: Processing page 3 of 5
# ---Series SE_GPI_TRATEA: Processing page 4 of 5
# ---Series SE_GPI_TRATEA: Processing page 5 of 5
# created file 2019.Q1.G.03\Indicator_4.5.1_Series_SE_GPI_TRATEA.json
# ---Series SH_DTH_NCOM: Processing page 1 of 7
# ---Series SH_DTH_NCOM: Processing page 2 of 7
# ---Series SH_DTH_NCOM: Processing page 3 of 7
# ---Series SH_DTH_NCOM: Processing page 4 of 7
# ---Series SH_DTH_NCOM: Processing page 5 of 7
# ---Series SH_DTH_NCOM: Processing page 6 of 7
# ---Series SH_DTH_NCOM: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_3.4.1_Series_SH_DTH_NCOM.json
# ---Series VC_DSR_BSDN: Processing page 1 of 2
# ---Series VC_DSR_BSDN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_BSDN.json
# ---Series ER_H2O_PARTIC: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.b.1_Series_ER_H2O_PARTIC.json
# ---Series ER_REG_UNFCIM: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_14.6.1_Series_ER_REG_UNFCIM.json
# ---Series AG_FPA_CFPI: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_2.c.1_Series_AG_FPA_CFPI.json
# ---Series SG_SCP_CORMEC: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_12.1.1_Series_SG_SCP_CORMEC.json
# ---Series SL_ISV_IFRM: Processing page 1 of 2
# ---Series SL_ISV_IFRM: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_8.3.1_Series_SL_ISV_IFRM.json
# ---Series ER_CBD_PTYPGRFA: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_15.6.1_Series_ER_CBD_PTYPGRFA.json
# ---Series SH_STA_WASTE: Processing page 1 of 2
# ---Series SH_STA_WASTE: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_2.2.2_Series_SH_STA_WASTE.json
# ---Series NV_IND_SSIS: Processing page 1 of 2
# ---Series NV_IND_SSIS: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_9.3.1_Series_NV_IND_SSIS.json
# ---Series AG_FPA_COMM: Processing page 1 of 5
# ---Series AG_FPA_COMM: Processing page 2 of 5
# ---Series AG_FPA_COMM: Processing page 3 of 5
# ---Series AG_FPA_COMM: Processing page 4 of 5
# ---Series AG_FPA_COMM: Processing page 5 of 5
# created file 2019.Q1.G.03\Indicator_2.c.1_Series_AG_FPA_COMM.json
# ---Series SH_STA_ASAIRP: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_3.9.1_Series_SH_STA_ASAIRP.json
# ---Series SE_ACC_ELEC: Processing page 1 of 4
# ---Series SE_ACC_ELEC: Processing page 2 of 4
# ---Series SE_ACC_ELEC: Processing page 3 of 4
# ---Series SE_ACC_ELEC: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_4.a.1_Series_SE_ACC_ELEC.json
# ---Series SH_DYN_MORT: Processing page 1 of 24
# ---Series SH_DYN_MORT: Processing page 2 of 24
# ---Series SH_DYN_MORT: Processing page 3 of 24
# ---Series SH_DYN_MORT: Processing page 4 of 24
# ---Series SH_DYN_MORT: Processing page 5 of 24
# ---Series SH_DYN_MORT: Processing page 6 of 24
# ---Series SH_DYN_MORT: Processing page 7 of 24
# ---Series SH_DYN_MORT: Processing page 8 of 24
# ---Series SH_DYN_MORT: Processing page 9 of 24
# ---Series SH_DYN_MORT: Processing page 10 of 24
# ---Series SH_DYN_MORT: Processing page 11 of 24
# ---Series SH_DYN_MORT: Processing page 12 of 24
# ---Series SH_DYN_MORT: Processing page 13 of 24
# ---Series SH_DYN_MORT: Processing page 14 of 24
# ---Series SH_DYN_MORT: Processing page 15 of 24
# ---Series SH_DYN_MORT: Processing page 16 of 24
# ---Series SH_DYN_MORT: Processing page 17 of 24
# ---Series SH_DYN_MORT: Processing page 18 of 24
# ---Series SH_DYN_MORT: Processing page 19 of 24
# ---Series SH_DYN_MORT: Processing page 20 of 24
# ---Series SH_DYN_MORT: Processing page 21 of 24
# ---Series SH_DYN_MORT: Processing page 22 of 24
# ---Series SH_DYN_MORT: Processing page 23 of 24
# ---Series SH_DYN_MORT: Processing page 24 of 24
# created file 2019.Q1.G.03\Indicator_3.2.1_Series_SH_DYN_MORT.json
# ---Series SG_DSR_LEGREG: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.5.3_Series_SG_DSR_LEGREG.json
# created file 2019.Q1.G.03\Indicator_11.b.1_Series_SG_DSR_LEGREG.json
# created file 2019.Q1.G.03\Indicator_13.1.2_Series_SG_DSR_LEGREG.json
# ---Series SG_HAZ_CMRSTHOLM: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_12.4.1_Series_SG_HAZ_CMRSTHOLM.json
# ---Series FI_FSI_FSKA: Processing page 1 of 3
# ---Series FI_FSI_FSKA: Processing page 2 of 3
# ---Series FI_FSI_FSKA: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_10.5.1_Series_FI_FSI_FSKA.json
# ---Series BX_TRF_PWKR: Processing page 1 of 11
# ---Series BX_TRF_PWKR: Processing page 2 of 11
# ---Series BX_TRF_PWKR: Processing page 3 of 11
# ---Series BX_TRF_PWKR: Processing page 4 of 11
# ---Series BX_TRF_PWKR: Processing page 5 of 11
# ---Series BX_TRF_PWKR: Processing page 6 of 11
# ---Series BX_TRF_PWKR: Processing page 7 of 11
# ---Series BX_TRF_PWKR: Processing page 8 of 11
# ---Series BX_TRF_PWKR: Processing page 9 of 11
# ---Series BX_TRF_PWKR: Processing page 10 of 11
# ---Series BX_TRF_PWKR: Processing page 11 of 11
# created file 2019.Q1.G.03\Indicator_17.3.2_Series_BX_TRF_PWKR.json
# ---Series IS_RDP_FRGVOL: Processing page 1 of 2
# ---Series IS_RDP_FRGVOL: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_9.1.2_Series_IS_RDP_FRGVOL.json
# ---Series DC_TRF_TOTL: Processing page 1 of 6
# ---Series DC_TRF_TOTL: Processing page 2 of 6
# ---Series DC_TRF_TOTL: Processing page 3 of 6
# ---Series DC_TRF_TOTL: Processing page 4 of 6
# ---Series DC_TRF_TOTL: Processing page 5 of 6
# ---Series DC_TRF_TOTL: Processing page 6 of 6
# created file 2019.Q1.G.03\Indicator_10.b.1_Series_DC_TRF_TOTL.json
# ---Series SH_STA_OVRWGT: Processing page 1 of 2
# ---Series SH_STA_OVRWGT: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_2.2.2_Series_SH_STA_OVRWGT.json
# ---Series VC_DSR_PDAN: Processing page 1 of 6
# ---Series VC_DSR_PDAN: Processing page 2 of 6
# ---Series VC_DSR_PDAN: Processing page 3 of 6
# ---Series VC_DSR_PDAN: Processing page 4 of 6
# ---Series VC_DSR_PDAN: Processing page 5 of 6
# ---Series VC_DSR_PDAN: Processing page 6 of 6
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_PDAN.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_PDAN.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_PDAN.json
# ---Series DC_ODA_LDCS: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.2.1_Series_DC_ODA_LDCS.json
# ---Series DC_TOF_SCHIPSL: Processing page 1 of 4
# ---Series DC_TOF_SCHIPSL: Processing page 2 of 4
# ---Series DC_TOF_SCHIPSL: Processing page 3 of 4
# ---Series DC_TOF_SCHIPSL: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_4.b.1_Series_DC_TOF_SCHIPSL.json
# ---Series SI_COV_SOCAST: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_SOCAST.json
# ---Series SI_HEI_TOTL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_10.1.1_Series_SI_HEI_TOTL.json
# ---Series VC_DSR_EFDN: Processing page 1 of 2
# ---Series VC_DSR_EFDN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_EFDN.json
# ---Series SH_DYN_IMRTN: Processing page 1 of 22
# ---Series SH_DYN_IMRTN: Processing page 2 of 22
# ---Series SH_DYN_IMRTN: Processing page 3 of 22
# ---Series SH_DYN_IMRTN: Processing page 4 of 22
# ---Series SH_DYN_IMRTN: Processing page 5 of 22
# ---Series SH_DYN_IMRTN: Processing page 6 of 22
# ---Series SH_DYN_IMRTN: Processing page 7 of 22
# ---Series SH_DYN_IMRTN: Processing page 8 of 22
# ---Series SH_DYN_IMRTN: Processing page 9 of 22
# ---Series SH_DYN_IMRTN: Processing page 10 of 22
# ---Series SH_DYN_IMRTN: Processing page 11 of 22
# ---Series SH_DYN_IMRTN: Processing page 12 of 22
# ---Series SH_DYN_IMRTN: Processing page 13 of 22
# ---Series SH_DYN_IMRTN: Processing page 14 of 22
# ---Series SH_DYN_IMRTN: Processing page 15 of 22
# ---Series SH_DYN_IMRTN: Processing page 16 of 22
# ---Series SH_DYN_IMRTN: Processing page 17 of 22
# ---Series SH_DYN_IMRTN: Processing page 18 of 22
# ---Series SH_DYN_IMRTN: Processing page 19 of 22
# ---Series SH_DYN_IMRTN: Processing page 20 of 22
# ---Series SH_DYN_IMRTN: Processing page 21 of 22
# ---Series SH_DYN_IMRTN: Processing page 22 of 22
# created file 2019.Q1.G.03\Indicator_3.2.1_Series_SH_DYN_IMRTN.json
# ---Series SL_EMP_PCAP: Processing page 1 of 8
# ---Series SL_EMP_PCAP: Processing page 2 of 8
# ---Series SL_EMP_PCAP: Processing page 3 of 8
# ---Series SL_EMP_PCAP: Processing page 4 of 8
# ---Series SL_EMP_PCAP: Processing page 5 of 8
# ---Series SL_EMP_PCAP: Processing page 6 of 8
# ---Series SL_EMP_PCAP: Processing page 7 of 8
# ---Series SL_EMP_PCAP: Processing page 8 of 8
# created file 2019.Q1.G.03\Indicator_8.2.1_Series_SL_EMP_PCAP.json
# ---Series ER_H2O_WUEYST: Processing page 1 of 3
# ---Series ER_H2O_WUEYST: Processing page 2 of 3
# ---Series ER_H2O_WUEYST: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_6.4.1_Series_ER_H2O_WUEYST.json
# ---Series TM_TAX_ATRFD: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.12.1_Series_TM_TAX_ATRFD.json
# ---Series NV_IND_TECH: Processing page 1 of 7
# ---Series NV_IND_TECH: Processing page 2 of 7
# ---Series NV_IND_TECH: Processing page 3 of 7
# ---Series NV_IND_TECH: Processing page 4 of 7
# ---Series NV_IND_TECH: Processing page 5 of 7
# ---Series NV_IND_TECH: Processing page 6 of 7
# ---Series NV_IND_TECH: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_9.b.1_Series_NV_IND_TECH.json
# ---Series SG_NHR_NOSTUSN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_16.a.1_Series_SG_NHR_NOSTUSN.json
# ---Series ER_UNK_LBRED: Processing page 1 of 12
# ---Series ER_UNK_LBRED: Processing page 2 of 12
# ---Series ER_UNK_LBRED: Processing page 3 of 12
# ---Series ER_UNK_LBRED: Processing page 4 of 12
# ---Series ER_UNK_LBRED: Processing page 5 of 12
# ---Series ER_UNK_LBRED: Processing page 6 of 12
# ---Series ER_UNK_LBRED: Processing page 7 of 12
# ---Series ER_UNK_LBRED: Processing page 8 of 12
# ---Series ER_UNK_LBRED: Processing page 9 of 12
# ---Series ER_UNK_LBRED: Processing page 10 of 12
# ---Series ER_UNK_LBRED: Processing page 11 of 12
# ---Series ER_UNK_LBRED: Processing page 12 of 12
# created file 2019.Q1.G.03\Indicator_2.5.2_Series_ER_UNK_LBRED.json
# ---Series DC_ODA_LLDC: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.2.1_Series_DC_ODA_LLDC.json
# ---Series EN_WBE_NDWTL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.6.1_Series_EN_WBE_NDWTL.json
# ---Series SI_COV_LMKTPQ: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_LMKTPQ.json
# ---Series SG_SCP_MACPOL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_12.1.1_Series_SG_SCP_MACPOL.json
# ---Series EN_WBE_PMPN: Processing page 1 of 7
# ---Series EN_WBE_PMPN: Processing page 2 of 7
# ---Series EN_WBE_PMPN: Processing page 3 of 7
# ---Series EN_WBE_PMPN: Processing page 4 of 7
# ---Series EN_WBE_PMPN: Processing page 5 of 7
# ---Series EN_WBE_PMPN: Processing page 6 of 7
# ---Series EN_WBE_PMPN: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_6.6.1_Series_EN_WBE_PMPN.json
# ---Series VC_DSR_DYHN: Processing page 1 of 39
# ---Series VC_DSR_DYHN: Processing page 2 of 39
# ---Series VC_DSR_DYHN: Processing page 3 of 39
# ---Series VC_DSR_DYHN: Processing page 4 of 39
# ---Series VC_DSR_DYHN: Processing page 5 of 39
# ---Series VC_DSR_DYHN: Processing page 6 of 39
# ---Series VC_DSR_DYHN: Processing page 7 of 39
# ---Series VC_DSR_DYHN: Processing page 8 of 39
# ---Series VC_DSR_DYHN: Processing page 9 of 39
# ---Series VC_DSR_DYHN: Processing page 10 of 39
# ---Series VC_DSR_DYHN: Processing page 11 of 39
# ---Series VC_DSR_DYHN: Processing page 12 of 39
# ---Series VC_DSR_DYHN: Processing page 13 of 39
# ---Series VC_DSR_DYHN: Processing page 14 of 39
# ---Series VC_DSR_DYHN: Processing page 15 of 39
# ---Series VC_DSR_DYHN: Processing page 16 of 39
# ---Series VC_DSR_DYHN: Processing page 17 of 39
# ---Series VC_DSR_DYHN: Processing page 18 of 39
# ---Series VC_DSR_DYHN: Processing page 19 of 39
# ---Series VC_DSR_DYHN: Processing page 20 of 39
# ---Series VC_DSR_DYHN: Processing page 21 of 39
# ---Series VC_DSR_DYHN: Processing page 22 of 39
# ---Series VC_DSR_DYHN: Processing page 23 of 39
# ---Series VC_DSR_DYHN: Processing page 24 of 39
# ---Series VC_DSR_DYHN: Processing page 25 of 39
# ---Series VC_DSR_DYHN: Processing page 26 of 39
# ---Series VC_DSR_DYHN: Processing page 27 of 39
# ---Series VC_DSR_DYHN: Processing page 28 of 39
# ---Series VC_DSR_DYHN: Processing page 29 of 39
# ---Series VC_DSR_DYHN: Processing page 30 of 39
# ---Series VC_DSR_DYHN: Processing page 31 of 39
# ---Series VC_DSR_DYHN: Processing page 32 of 39
# ---Series VC_DSR_DYHN: Processing page 33 of 39
# ---Series VC_DSR_DYHN: Processing page 34 of 39
# ---Series VC_DSR_DYHN: Processing page 35 of 39
# ---Series VC_DSR_DYHN: Processing page 36 of 39
# ---Series VC_DSR_DYHN: Processing page 37 of 39
# ---Series VC_DSR_DYHN: Processing page 38 of 39
# ---Series VC_DSR_DYHN: Processing page 39 of 39
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_DYHN.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_DYHN.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_DYHN.json
# ---Series VC_DSR_CILN: Processing page 1 of 4
# ---Series VC_DSR_CILN: Processing page 2 of 4
# ---Series VC_DSR_CILN: Processing page 3 of 4
# ---Series VC_DSR_CILN: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_1.5.2_Series_VC_DSR_CILN.json
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_CILN.json
# ---Series SI_COV_BENFTS: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_BENFTS.json
# ---Series VC_DSR_ESDN: Processing page 1 of 2
# ---Series VC_DSR_ESDN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_ESDN.json
# ---Series SH_MED_HEAWOR: Processing page 1 of 10
# ---Series SH_MED_HEAWOR: Processing page 2 of 10
# ---Series SH_MED_HEAWOR: Processing page 3 of 10
# ---Series SH_MED_HEAWOR: Processing page 4 of 10
# ---Series SH_MED_HEAWOR: Processing page 5 of 10
# ---Series SH_MED_HEAWOR: Processing page 6 of 10
# ---Series SH_MED_HEAWOR: Processing page 7 of 10
# ---Series SH_MED_HEAWOR: Processing page 8 of 10
# ---Series SH_MED_HEAWOR: Processing page 9 of 10
# ---Series SH_MED_HEAWOR: Processing page 10 of 10
# created file 2019.Q1.G.03\Indicator_3.c.1_Series_SH_MED_HEAWOR.json
# ---Series SH_IHR_CAPS: Processing page 1 of 30
# ---Series SH_IHR_CAPS: Processing page 2 of 30
# ---Series SH_IHR_CAPS: Processing page 3 of 30
# ---Series SH_IHR_CAPS: Processing page 4 of 30
# ---Series SH_IHR_CAPS: Processing page 5 of 30
# ---Series SH_IHR_CAPS: Processing page 6 of 30
# ---Series SH_IHR_CAPS: Processing page 7 of 30
# ---Series SH_IHR_CAPS: Processing page 8 of 30
# ---Series SH_IHR_CAPS: Processing page 9 of 30
# ---Series SH_IHR_CAPS: Processing page 10 of 30
# ---Series SH_IHR_CAPS: Processing page 11 of 30
# ---Series SH_IHR_CAPS: Processing page 12 of 30
# ---Series SH_IHR_CAPS: Processing page 13 of 30
# ---Series SH_IHR_CAPS: Processing page 14 of 30
# ---Series SH_IHR_CAPS: Processing page 15 of 30
# ---Series SH_IHR_CAPS: Processing page 16 of 30
# ---Series SH_IHR_CAPS: Processing page 17 of 30
# ---Series SH_IHR_CAPS: Processing page 18 of 30
# ---Series SH_IHR_CAPS: Processing page 19 of 30
# ---Series SH_IHR_CAPS: Processing page 20 of 30
# ---Series SH_IHR_CAPS: Processing page 21 of 30
# ---Series SH_IHR_CAPS: Processing page 22 of 30
# ---Series SH_IHR_CAPS: Processing page 23 of 30
# ---Series SH_IHR_CAPS: Processing page 24 of 30
# ---Series SH_IHR_CAPS: Processing page 25 of 30
# ---Series SH_IHR_CAPS: Processing page 26 of 30
# ---Series SH_IHR_CAPS: Processing page 27 of 30
# ---Series SH_IHR_CAPS: Processing page 28 of 30
# ---Series SH_IHR_CAPS: Processing page 29 of 30
# ---Series SH_IHR_CAPS: Processing page 30 of 30
# created file 2019.Q1.G.03\Indicator_3.d.1_Series_SH_IHR_CAPS.json
# ---Series EG_TBA_H2CORL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.5.2_Series_EG_TBA_H2CORL.json
# ---Series ER_RSK_LSTI: Processing page 1 of 41
# ---Series ER_RSK_LSTI: Processing page 2 of 41
# ---Series ER_RSK_LSTI: Processing page 3 of 41
# ---Series ER_RSK_LSTI: Processing page 4 of 41
# ---Series ER_RSK_LSTI: Processing page 5 of 41
# ---Series ER_RSK_LSTI: Processing page 6 of 41
# ---Series ER_RSK_LSTI: Processing page 7 of 41
# ---Series ER_RSK_LSTI: Processing page 8 of 41
# ---Series ER_RSK_LSTI: Processing page 9 of 41
# ---Series ER_RSK_LSTI: Processing page 10 of 41
# ---Series ER_RSK_LSTI: Processing page 11 of 41
# ---Series ER_RSK_LSTI: Processing page 12 of 41
# ---Series ER_RSK_LSTI: Processing page 13 of 41
# ---Series ER_RSK_LSTI: Processing page 14 of 41
# ---Series ER_RSK_LSTI: Processing page 15 of 41
# ---Series ER_RSK_LSTI: Processing page 16 of 41
# ---Series ER_RSK_LSTI: Processing page 17 of 41
# ---Series ER_RSK_LSTI: Processing page 18 of 41
# ---Series ER_RSK_LSTI: Processing page 19 of 41
# ---Series ER_RSK_LSTI: Processing page 20 of 41
# ---Series ER_RSK_LSTI: Processing page 21 of 41
# ---Series ER_RSK_LSTI: Processing page 22 of 41
# ---Series ER_RSK_LSTI: Processing page 23 of 41
# ---Series ER_RSK_LSTI: Processing page 24 of 41
# ---Series ER_RSK_LSTI: Processing page 25 of 41
# ---Series ER_RSK_LSTI: Processing page 26 of 41
# ---Series ER_RSK_LSTI: Processing page 27 of 41
# ---Series ER_RSK_LSTI: Processing page 28 of 41
# ---Series ER_RSK_LSTI: Processing page 29 of 41
# ---Series ER_RSK_LSTI: Processing page 30 of 41
# ---Series ER_RSK_LSTI: Processing page 31 of 41
# ---Series ER_RSK_LSTI: Processing page 32 of 41
# ---Series ER_RSK_LSTI: Processing page 33 of 41
# ---Series ER_RSK_LSTI: Processing page 34 of 41
# ---Series ER_RSK_LSTI: Processing page 35 of 41
# ---Series ER_RSK_LSTI: Processing page 36 of 41
# ---Series ER_RSK_LSTI: Processing page 37 of 41
# ---Series ER_RSK_LSTI: Processing page 38 of 41
# ---Series ER_RSK_LSTI: Processing page 39 of 41
# ---Series ER_RSK_LSTI: Processing page 40 of 41
# ---Series ER_RSK_LSTI: Processing page 41 of 41
# created file 2019.Q1.G.03\Indicator_15.5.1_Series_ER_RSK_LSTI.json
# ---Series ER_H2O_PRDU: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.b.1_Series_ER_H2O_PRDU.json
# ---Series EN_H2O_OPAMBQ: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.3.2_Series_EN_H2O_OPAMBQ.json
# ---Series EN_WBE_NDQLRVR: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.6.1_Series_EN_WBE_NDQLRVR.json
# ---Series SI_COV_VULN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_VULN.json
# ---Series SH_DTH_RNCOM: Processing page 1 of 26
# ---Series SH_DTH_RNCOM: Processing page 2 of 26
# ---Series SH_DTH_RNCOM: Processing page 3 of 26
# ---Series SH_DTH_RNCOM: Processing page 4 of 26
# ---Series SH_DTH_RNCOM: Processing page 5 of 26
# ---Series SH_DTH_RNCOM: Processing page 6 of 26
# ---Series SH_DTH_RNCOM: Processing page 7 of 26
# ---Series SH_DTH_RNCOM: Processing page 8 of 26
# ---Series SH_DTH_RNCOM: Processing page 9 of 26
# ---Series SH_DTH_RNCOM: Processing page 10 of 26
# ---Series SH_DTH_RNCOM: Processing page 11 of 26
# ---Series SH_DTH_RNCOM: Processing page 12 of 26
# ---Series SH_DTH_RNCOM: Processing page 13 of 26
# ---Series SH_DTH_RNCOM: Processing page 14 of 26
# ---Series SH_DTH_RNCOM: Processing page 15 of 26
# ---Series SH_DTH_RNCOM: Processing page 16 of 26
# ---Series SH_DTH_RNCOM: Processing page 17 of 26
# ---Series SH_DTH_RNCOM: Processing page 18 of 26
# ---Series SH_DTH_RNCOM: Processing page 19 of 26
# ---Series SH_DTH_RNCOM: Processing page 20 of 26
# ---Series SH_DTH_RNCOM: Processing page 21 of 26
# ---Series SH_DTH_RNCOM: Processing page 22 of 26
# ---Series SH_DTH_RNCOM: Processing page 23 of 26
# ---Series SH_DTH_RNCOM: Processing page 24 of 26
# ---Series SH_DTH_RNCOM: Processing page 25 of 26
# ---Series SH_DTH_RNCOM: Processing page 26 of 26
# created file 2019.Q1.G.03\Indicator_3.4.1_Series_SH_DTH_RNCOM.json
# ---Series VC_DSR_DADN: Processing page 1 of 6
# ---Series VC_DSR_DADN: Processing page 2 of 6
# ---Series VC_DSR_DADN: Processing page 3 of 6
# ---Series VC_DSR_DADN: Processing page 4 of 6
# ---Series VC_DSR_DADN: Processing page 5 of 6
# ---Series VC_DSR_DADN: Processing page 6 of 6
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_DADN.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_DADN.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_DADN.json
# ---Series SI_COV_MATNL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_MATNL.json
# ---Series SE_ACC_HNWA: Processing page 1 of 3
# ---Series SE_ACC_HNWA: Processing page 2 of 3
# ---Series SE_ACC_HNWA: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_4.a.1_Series_SE_ACC_HNWA.json
# ---Series FI_FSI_FSSNO: Processing page 1 of 3
# ---Series FI_FSI_FSSNO: Processing page 2 of 3
# ---Series FI_FSI_FSSNO: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_10.5.1_Series_FI_FSI_FSSNO.json
# ---Series ER_NRK_LBREDN: Processing page 1 of 12
# ---Series ER_NRK_LBREDN: Processing page 2 of 12
# ---Series ER_NRK_LBREDN: Processing page 3 of 12
# ---Series ER_NRK_LBREDN: Processing page 4 of 12
# ---Series ER_NRK_LBREDN: Processing page 5 of 12
# ---Series ER_NRK_LBREDN: Processing page 6 of 12
# ---Series ER_NRK_LBREDN: Processing page 7 of 12
# ---Series ER_NRK_LBREDN: Processing page 8 of 12
# ---Series ER_NRK_LBREDN: Processing page 9 of 12
# ---Series ER_NRK_LBREDN: Processing page 10 of 12
# ---Series ER_NRK_LBREDN: Processing page 11 of 12
# ---Series ER_NRK_LBREDN: Processing page 12 of 12
# created file 2019.Q1.G.03\Indicator_2.5.2_Series_ER_NRK_LBREDN.json
# ---Series SL_TLF_CHLDEA: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_8.7.1_Series_SL_TLF_CHLDEA.json
# ---Series SI_COV_CHLD: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_CHLD.json
# ---Series VC_DSR_CDYN: Processing page 1 of 2
# ---Series VC_DSR_CDYN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_CDYN.json
# ---Series SI_COV_SOCASTPQ: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.3.1_Series_SI_COV_SOCASTPQ.json
# ---Series SH_DYN_IMRT: Processing page 1 of 24
# ---Series SH_DYN_IMRT: Processing page 2 of 24
# ---Series SH_DYN_IMRT: Processing page 3 of 24
# ---Series SH_DYN_IMRT: Processing page 4 of 24
# ---Series SH_DYN_IMRT: Processing page 5 of 24
# ---Series SH_DYN_IMRT: Processing page 6 of 24
# ---Series SH_DYN_IMRT: Processing page 7 of 24
# ---Series SH_DYN_IMRT: Processing page 8 of 24
# ---Series SH_DYN_IMRT: Processing page 9 of 24
# ---Series SH_DYN_IMRT: Processing page 10 of 24
# ---Series SH_DYN_IMRT: Processing page 11 of 24
# ---Series SH_DYN_IMRT: Processing page 12 of 24
# ---Series SH_DYN_IMRT: Processing page 13 of 24
# ---Series SH_DYN_IMRT: Processing page 14 of 24
# ---Series SH_DYN_IMRT: Processing page 15 of 24
# ---Series SH_DYN_IMRT: Processing page 16 of 24
# ---Series SH_DYN_IMRT: Processing page 17 of 24
# ---Series SH_DYN_IMRT: Processing page 18 of 24
# ---Series SH_DYN_IMRT: Processing page 19 of 24
# ---Series SH_DYN_IMRT: Processing page 20 of 24
# ---Series SH_DYN_IMRT: Processing page 21 of 24
# ---Series SH_DYN_IMRT: Processing page 22 of 24
# ---Series SH_DYN_IMRT: Processing page 23 of 24
# ---Series SH_DYN_IMRT: Processing page 24 of 24
# created file 2019.Q1.G.03\Indicator_3.2.1_Series_SH_DYN_IMRT.json
# ---Series GF_XPD_GBPC: Processing page 1 of 2
# ---Series GF_XPD_GBPC: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_16.6.1_Series_GF_XPD_GBPC.json
# ---Series VC_DSR_AFFCT: Processing page 1 of 6
# ---Series VC_DSR_AFFCT: Processing page 2 of 6
# ---Series VC_DSR_AFFCT: Processing page 3 of 6
# ---Series VC_DSR_AFFCT: Processing page 4 of 6
# ---Series VC_DSR_AFFCT: Processing page 5 of 6
# ---Series VC_DSR_AFFCT: Processing page 6 of 6
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_AFFCT.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_AFFCT.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_AFFCT.json
# ---Series SH_PRV_SMOK: Processing page 1 of 4
# ---Series SH_PRV_SMOK: Processing page 2 of 4
# ---Series SH_PRV_SMOK: Processing page 3 of 4
# ---Series SH_PRV_SMOK: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_3.a.1_Series_SH_PRV_SMOK.json
# ---Series SG_NHR_IMPL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_16.a.1_Series_SG_NHR_IMPL.json
# ---Series ER_H2O_STRESS: Processing page 1 of 3
# ---Series ER_H2O_STRESS: Processing page 2 of 3
# ---Series ER_H2O_STRESS: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_6.4.2_Series_ER_H2O_STRESS.json
# ---Series SH_ACS_UNHC: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_3.8.1_Series_SH_ACS_UNHC.json
# ---Series ER_H2O_IWRMD: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.5.1_Series_ER_H2O_IWRMD.json
# ---Series EN_WBE_PMNR: Processing page 1 of 7
# ---Series EN_WBE_PMNR: Processing page 2 of 7
# ---Series EN_WBE_PMNR: Processing page 3 of 7
# ---Series EN_WBE_PMNR: Processing page 4 of 7
# ---Series EN_WBE_PMNR: Processing page 5 of 7
# ---Series EN_WBE_PMNR: Processing page 6 of 7
# ---Series EN_WBE_PMNR: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_6.6.1_Series_EN_WBE_PMNR.json
# ---Series VC_DSR_AGLN: Processing page 1 of 4
# ---Series VC_DSR_AGLN: Processing page 2 of 4
# ---Series VC_DSR_AGLN: Processing page 3 of 4
# ---Series VC_DSR_AGLN: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_1.5.2_Series_VC_DSR_AGLN.json
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_AGLN.json
# ---Series VC_DSR_CDAN: Processing page 1 of 2
# ---Series VC_DSR_CDAN: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_CDAN.json
# ---Series ER_PTD_MOTN: Processing page 1 of 24
# ---Series ER_PTD_MOTN: Processing page 2 of 24
# ---Series ER_PTD_MOTN: Processing page 3 of 24
# ---Series ER_PTD_MOTN: Processing page 4 of 24
# ---Series ER_PTD_MOTN: Processing page 5 of 24
# ---Series ER_PTD_MOTN: Processing page 6 of 24
# ---Series ER_PTD_MOTN: Processing page 7 of 24
# ---Series ER_PTD_MOTN: Processing page 8 of 24
# ---Series ER_PTD_MOTN: Processing page 9 of 24
# ---Series ER_PTD_MOTN: Processing page 10 of 24
# ---Series ER_PTD_MOTN: Processing page 11 of 24
# ---Series ER_PTD_MOTN: Processing page 12 of 24
# ---Series ER_PTD_MOTN: Processing page 13 of 24
# ---Series ER_PTD_MOTN: Processing page 14 of 24
# ---Series ER_PTD_MOTN: Processing page 15 of 24
# ---Series ER_PTD_MOTN: Processing page 16 of 24
# ---Series ER_PTD_MOTN: Processing page 17 of 24
# ---Series ER_PTD_MOTN: Processing page 18 of 24
# ---Series ER_PTD_MOTN: Processing page 19 of 24
# ---Series ER_PTD_MOTN: Processing page 20 of 24
# ---Series ER_PTD_MOTN: Processing page 21 of 24
# ---Series ER_PTD_MOTN: Processing page 22 of 24
# ---Series ER_PTD_MOTN: Processing page 23 of 24
# ---Series ER_PTD_MOTN: Processing page 24 of 24
# created file 2019.Q1.G.03\Indicator_15.4.1_Series_ER_PTD_MOTN.json
# ---Series SH_STA_OVRWGTN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_2.2.2_Series_SH_STA_OVRWGTN.json
# ---Series EG_TBA_H2CO: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.5.2_Series_EG_TBA_H2CO.json
# ---Series AG_LND_FRST: Processing page 1 of 3
# ---Series AG_LND_FRST: Processing page 2 of 3
# ---Series AG_LND_FRST: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_15.1.1_Series_AG_LND_FRST.json
# ---Series AG_PRD_FIESSI: Processing page 1 of 2
# ---Series AG_PRD_FIESSI: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_2.1.2_Series_AG_PRD_FIESSI.json
# ---Series SG_SCP_POLINS: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_12.1.1_Series_SG_SCP_POLINS.json
# ---Series SE_ADT_EDUCTRN: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_4.3.1_Series_SE_ADT_EDUCTRN.json
# ---Series EN_WBE_PMPR: Processing page 1 of 7
# ---Series EN_WBE_PMPR: Processing page 2 of 7
# ---Series EN_WBE_PMPR: Processing page 3 of 7
# ---Series EN_WBE_PMPR: Processing page 4 of 7
# ---Series EN_WBE_PMPR: Processing page 5 of 7
# ---Series EN_WBE_PMPR: Processing page 6 of 7
# ---Series EN_WBE_PMPR: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_6.6.1_Series_EN_WBE_PMPR.json
# ---Series DC_TOF_TRDDBMDL: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_8.a.1_Series_DC_TOF_TRDDBMDL.json
# ---Series SH_STA_SCIDEN: Processing page 1 of 7
# ---Series SH_STA_SCIDEN: Processing page 2 of 7
# ---Series SH_STA_SCIDEN: Processing page 3 of 7
# ---Series SH_STA_SCIDEN: Processing page 4 of 7
# ---Series SH_STA_SCIDEN: Processing page 5 of 7
# ---Series SH_STA_SCIDEN: Processing page 6 of 7
# ---Series SH_STA_SCIDEN: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_3.4.2_Series_SH_STA_SCIDEN.json
# ---Series SI_RMT_COST: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_10.c.1_Series_SI_RMT_COST.json
# ---Series FB_ATM_TOTL: Processing page 1 of 5
# ---Series FB_ATM_TOTL: Processing page 2 of 5
# ---Series FB_ATM_TOTL: Processing page 3 of 5
# ---Series FB_ATM_TOTL: Processing page 4 of 5
# ---Series FB_ATM_TOTL: Processing page 5 of 5
# created file 2019.Q1.G.03\Indicator_8.10.1_Series_FB_ATM_TOTL.json
# ---Series VC_DSR_AGLH: Processing page 1 of 26
# ---Series VC_DSR_AGLH: Processing page 2 of 26
# ---Series VC_DSR_AGLH: Processing page 3 of 26
# ---Series VC_DSR_AGLH: Processing page 4 of 26
# ---Series VC_DSR_AGLH: Processing page 5 of 26
# ---Series VC_DSR_AGLH: Processing page 6 of 26
# ---Series VC_DSR_AGLH: Processing page 7 of 26
# ---Series VC_DSR_AGLH: Processing page 8 of 26
# ---Series VC_DSR_AGLH: Processing page 9 of 26
# ---Series VC_DSR_AGLH: Processing page 10 of 26
# ---Series VC_DSR_AGLH: Processing page 11 of 26
# ---Series VC_DSR_AGLH: Processing page 12 of 26
# ---Series VC_DSR_AGLH: Processing page 13 of 26
# ---Series VC_DSR_AGLH: Processing page 14 of 26
# ---Series VC_DSR_AGLH: Processing page 15 of 26
# ---Series VC_DSR_AGLH: Processing page 16 of 26
# ---Series VC_DSR_AGLH: Processing page 17 of 26
# ---Series VC_DSR_AGLH: Processing page 18 of 26
# ---Series VC_DSR_AGLH: Processing page 19 of 26
# ---Series VC_DSR_AGLH: Processing page 20 of 26
# ---Series VC_DSR_AGLH: Processing page 21 of 26
# ---Series VC_DSR_AGLH: Processing page 22 of 26
# ---Series VC_DSR_AGLH: Processing page 23 of 26
# ---Series VC_DSR_AGLH: Processing page 24 of 26
# ---Series VC_DSR_AGLH: Processing page 25 of 26
# ---Series VC_DSR_AGLH: Processing page 26 of 26
# created file 2019.Q1.G.03\Indicator_1.5.2_Series_VC_DSR_AGLH.json
# created file 2019.Q1.G.03\Indicator_11.5.2_Series_VC_DSR_AGLH.json
# ---Series DC_ODA_LLDCG: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.2.1_Series_DC_ODA_LLDCG.json
# ---Series SG_PLN_PRVRICTRY: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_17.15.1_Series_SG_PLN_PRVRICTRY.json
# ---Series ER_PTD_FRWRT: Processing page 1 of 19
# ---Series ER_PTD_FRWRT: Processing page 2 of 19
# ---Series ER_PTD_FRWRT: Processing page 3 of 19
# ---Series ER_PTD_FRWRT: Processing page 4 of 19
# ---Series ER_PTD_FRWRT: Processing page 5 of 19
# ---Series ER_PTD_FRWRT: Processing page 6 of 19
# ---Series ER_PTD_FRWRT: Processing page 7 of 19
# ---Series ER_PTD_FRWRT: Processing page 8 of 19
# ---Series ER_PTD_FRWRT: Processing page 9 of 19
# ---Series ER_PTD_FRWRT: Processing page 10 of 19
# ---Series ER_PTD_FRWRT: Processing page 11 of 19
# ---Series ER_PTD_FRWRT: Processing page 12 of 19
# ---Series ER_PTD_FRWRT: Processing page 13 of 19
# ---Series ER_PTD_FRWRT: Processing page 14 of 19
# ---Series ER_PTD_FRWRT: Processing page 15 of 19
# ---Series ER_PTD_FRWRT: Processing page 16 of 19
# ---Series ER_PTD_FRWRT: Processing page 17 of 19
# ---Series ER_PTD_FRWRT: Processing page 18 of 19
# ---Series ER_PTD_FRWRT: Processing page 19 of 19
# created file 2019.Q1.G.03\Indicator_15.1.2_Series_ER_PTD_FRWRT.json
# ---Series IT_USE_ii99: Processing page 1 of 9
# ---Series IT_USE_ii99: Processing page 2 of 9
# ---Series IT_USE_ii99: Processing page 3 of 9
# ---Series IT_USE_ii99: Processing page 4 of 9
# ---Series IT_USE_ii99: Processing page 5 of 9
# ---Series IT_USE_ii99: Processing page 6 of 9
# ---Series IT_USE_ii99: Processing page 7 of 9
# ---Series IT_USE_ii99: Processing page 8 of 9
# ---Series IT_USE_ii99: Processing page 9 of 9
# created file 2019.Q1.G.03\Indicator_17.8.1_Series_IT_USE_ii99.json
# ---Series IT_NET_BBN: Processing page 1 of 13
# ---Series IT_NET_BBN: Processing page 2 of 13
# ---Series IT_NET_BBN: Processing page 3 of 13
# ---Series IT_NET_BBN: Processing page 4 of 13
# ---Series IT_NET_BBN: Processing page 5 of 13
# ---Series IT_NET_BBN: Processing page 6 of 13
# ---Series IT_NET_BBN: Processing page 7 of 13
# ---Series IT_NET_BBN: Processing page 8 of 13
# ---Series IT_NET_BBN: Processing page 9 of 13
# ---Series IT_NET_BBN: Processing page 10 of 13
# ---Series IT_NET_BBN: Processing page 11 of 13
# ---Series IT_NET_BBN: Processing page 12 of 13
# ---Series IT_NET_BBN: Processing page 13 of 13
# created file 2019.Q1.G.03\Indicator_17.6.2_Series_IT_NET_BBN.json
# ---Series IC_FRM_BRIB: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_16.5.2_Series_IC_FRM_BRIB.json
# ---Series EN_ATM_PM25: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_11.6.2_Series_EN_ATM_PM25.json
# ---Series SL_EMP_GTOTL: Processing page 1 of 2
# ---Series SL_EMP_GTOTL: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_10.4.1_Series_SL_EMP_GTOTL.json
# ---Series SL_DOM_TSPDCW: Processing page 1 of 4
# ---Series SL_DOM_TSPDCW: Processing page 2 of 4
# ---Series SL_DOM_TSPDCW: Processing page 3 of 4
# ---Series SL_DOM_TSPDCW: Processing page 4 of 4
# created file 2019.Q1.G.03\Indicator_5.4.1_Series_SL_DOM_TSPDCW.json
# ---Series EN_ATM_CO2: Processing page 1 of 7
# ---Series EN_ATM_CO2: Processing page 2 of 7
# ---Series EN_ATM_CO2: Processing page 3 of 7
# ---Series EN_ATM_CO2: Processing page 4 of 7
# ---Series EN_ATM_CO2: Processing page 5 of 7
# ---Series EN_ATM_CO2: Processing page 6 of 7
# ---Series EN_ATM_CO2: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_9.4.1_Series_EN_ATM_CO2.json
# ---Series SG_GOV_LOGV: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_1.5.4_Series_SG_GOV_LOGV.json
# created file 2019.Q1.G.03\Indicator_11.b.2_Series_SG_GOV_LOGV.json
# created file 2019.Q1.G.03\Indicator_13.1.3_Series_SG_GOV_LOGV.json
# ---Series ER_WAT_PRDU: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_6.b.1_Series_ER_WAT_PRDU.json
# ---Series SE_URP_REAACH: Processing page 1 of 2
# ---Series SE_URP_REAACH: Processing page 2 of 2
# created file 2019.Q1.G.03\Indicator_4.5.1_Series_SE_URP_REAACH.json
# ---Series DC_TOF_AGRL: Processing page 1 of 7
# ---Series DC_TOF_AGRL: Processing page 2 of 7
# ---Series DC_TOF_AGRL: Processing page 3 of 7
# ---Series DC_TOF_AGRL: Processing page 4 of 7
# ---Series DC_TOF_AGRL: Processing page 5 of 7
# ---Series DC_TOF_AGRL: Processing page 6 of 7
# ---Series DC_TOF_AGRL: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_2.a.2_Series_DC_TOF_AGRL.json
# ---Series SH_IHR_CAPPRD: Processing page 1 of 3
# ---Series SH_IHR_CAPPRD: Processing page 2 of 3
# ---Series SH_IHR_CAPPRD: Processing page 3 of 3
# created file 2019.Q1.G.03\Indicator_3.d.1_Series_SH_IHR_CAPPRD.json
# ---Series VC_DSR_MMHN: Processing page 1 of 39
# ---Series VC_DSR_MMHN: Processing page 2 of 39
# ---Series VC_DSR_MMHN: Processing page 3 of 39
# ---Series VC_DSR_MMHN: Processing page 4 of 39
# ---Series VC_DSR_MMHN: Processing page 5 of 39
# ---Series VC_DSR_MMHN: Processing page 6 of 39
# ...
# ---Series EN_MAT_DOMCMPT: Processing page 10 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 11 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 12 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 13 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 14 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 15 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 16 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 17 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 18 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 19 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 20 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 21 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 22 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 23 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 24 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 25 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 26 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 27 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 28 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 29 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 30 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 31 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 32 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 33 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 34 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 35 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 36 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 37 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 38 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 39 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 40 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 41 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 42 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 43 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 44 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 45 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 46 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 47 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 48 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 49 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 50 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 51 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 52 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 53 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 54 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 55 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 56 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 57 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 58 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 59 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 60 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 61 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 62 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 63 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 64 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 65 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 66 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 67 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 68 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 69 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 70 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 71 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 72 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 73 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 74 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 75 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 76 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 77 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 78 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 79 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 80 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 81 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 82 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 83 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 84 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 85 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 86 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 87 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 88 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 89 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 90 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 91 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 92 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 93 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 94 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 95 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 96 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 97 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 98 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 99 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 100 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 101 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 102 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 103 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 104 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 105 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 106 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 107 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 108 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 109 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 110 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 111 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 112 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 113 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 114 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 115 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 116 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 117 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 118 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 119 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 120 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 121 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 122 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 123 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 124 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 125 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 126 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 127 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 128 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 129 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 130 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 131 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 132 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 133 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 134 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 135 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 136 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 137 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 138 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 139 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 140 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 141 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 142 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 143 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 144 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 145 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 146 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 147 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 148 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 149 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 150 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 151 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 152 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 153 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 154 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 155 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 156 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 157 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 158 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 159 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 160 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 161 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 162 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 163 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 164 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 165 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 166 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 167 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 168 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 169 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 170 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 171 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 172 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 173 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 174 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 175 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 176 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 177 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 178 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 179 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 180 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 181 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 182 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 183 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 184 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 185 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 186 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 187 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 188 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 189 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 190 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 191 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 192 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 193 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 194 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 195 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 196 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 197 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 198 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 199 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 200 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 201 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 202 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 203 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 204 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 205 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 206 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 207 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 208 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 209 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 210 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 211 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 212 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 213 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 214 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 215 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 216 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 217 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 218 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 219 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 220 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 221 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 222 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 223 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 224 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 225 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 226 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 227 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 228 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 229 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 230 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 231 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 232 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 233 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 234 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 235 of 236
# ---Series EN_MAT_DOMCMPT: Processing page 236 of 236
# created file 2019.Q1.G.03\Indicator_12.2.2_Series_EN_MAT_DOMCMPT.json
# created file 2019.Q1.G.03\Indicator_8.4.2_Series_EN_MAT_DOMCMPT.json
# ---Series SE_IMP_FPOF: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_4.5.1_Series_SE_IMP_FPOF.json
# ---Series AG_PRD_XSUBDY: Processing page 1 of 1
# created file 2019.Q1.G.03\Indicator_2.b.1_Series_AG_PRD_XSUBDY.json
# ---Series VC_DSR_PDLN: Processing page 1 of 6
# ---Series VC_DSR_PDLN: Processing page 2 of 6
# ---Series VC_DSR_PDLN: Processing page 3 of 6
# ---Series VC_DSR_PDLN: Processing page 4 of 6
# ---Series VC_DSR_PDLN: Processing page 5 of 6
# ---Series VC_DSR_PDLN: Processing page 6 of 6
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_PDLN.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_PDLN.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_PDLN.json
# ---Series IT_NET_BBP: Processing page 1 of 14
# ---Series IT_NET_BBP: Processing page 2 of 14
# ---Series IT_NET_BBP: Processing page 3 of 14
# ---Series IT_NET_BBP: Processing page 4 of 14
# ---Series IT_NET_BBP: Processing page 5 of 14
# ---Series IT_NET_BBP: Processing page 6 of 14
# ---Series IT_NET_BBP: Processing page 7 of 14
# ---Series IT_NET_BBP: Processing page 8 of 14
# ---Series IT_NET_BBP: Processing page 9 of 14
# ---Series IT_NET_BBP: Processing page 10 of 14
# ---Series IT_NET_BBP: Processing page 11 of 14
# ---Series IT_NET_BBP: Processing page 12 of 14
# ---Series IT_NET_BBP: Processing page 13 of 14
# ---Series IT_NET_BBP: Processing page 14 of 14
# created file 2019.Q1.G.03\Indicator_17.6.2_Series_IT_NET_BBP.json
# ---Series VC_DSR_DDHN: Processing page 1 of 39
# ---Series VC_DSR_DDHN: Processing page 2 of 39
# ---Series VC_DSR_DDHN: Processing page 3 of 39
# ---Series VC_DSR_DDHN: Processing page 4 of 39
# ---Series VC_DSR_DDHN: Processing page 5 of 39
# ---Series VC_DSR_DDHN: Processing page 6 of 39
# ---Series VC_DSR_DDHN: Processing page 7 of 39
# ---Series VC_DSR_DDHN: Processing page 8 of 39
# ---Series VC_DSR_DDHN: Processing page 9 of 39
# ---Series VC_DSR_DDHN: Processing page 10 of 39
# ---Series VC_DSR_DDHN: Processing page 11 of 39
# ---Series VC_DSR_DDHN: Processing page 12 of 39
# ---Series VC_DSR_DDHN: Processing page 13 of 39
# ---Series VC_DSR_DDHN: Processing page 14 of 39
# ---Series VC_DSR_DDHN: Processing page 15 of 39
# ---Series VC_DSR_DDHN: Processing page 16 of 39
# ---Series VC_DSR_DDHN: Processing page 17 of 39
# ---Series VC_DSR_DDHN: Processing page 18 of 39
# ---Series VC_DSR_DDHN: Processing page 19 of 39
# ---Series VC_DSR_DDHN: Processing page 20 of 39
# ---Series VC_DSR_DDHN: Processing page 21 of 39
# ---Series VC_DSR_DDHN: Processing page 22 of 39
# ---Series VC_DSR_DDHN: Processing page 23 of 39
# ---Series VC_DSR_DDHN: Processing page 24 of 39
# ---Series VC_DSR_DDHN: Processing page 25 of 39
# ---Series VC_DSR_DDHN: Processing page 26 of 39
# ---Series VC_DSR_DDHN: Processing page 27 of 39
# ---Series VC_DSR_DDHN: Processing page 28 of 39
# ---Series VC_DSR_DDHN: Processing page 29 of 39
# ---Series VC_DSR_DDHN: Processing page 30 of 39
# ---Series VC_DSR_DDHN: Processing page 31 of 39
# ---Series VC_DSR_DDHN: Processing page 32 of 39
# ---Series VC_DSR_DDHN: Processing page 33 of 39
# ---Series VC_DSR_DDHN: Processing page 34 of 39
# ---Series VC_DSR_DDHN: Processing page 35 of 39
# ---Series VC_DSR_DDHN: Processing page 36 of 39
# ---Series VC_DSR_DDHN: Processing page 37 of 39
# ---Series VC_DSR_DDHN: Processing page 38 of 39
# ---Series VC_DSR_DDHN: Processing page 39 of 39
# created file 2019.Q1.G.03\Indicator_1.5.1_Series_VC_DSR_DDHN.json
# created file 2019.Q1.G.03\Indicator_11.5.1_Series_VC_DSR_DDHN.json
# created file 2019.Q1.G.03\Indicator_13.1.1_Series_VC_DSR_DDHN.json
# ---Series SL_EMP_INJUR: Processing page 1 of 7
# ---Series SL_EMP_INJUR: Processing page 2 of 7
# ---Series SL_EMP_INJUR: Processing page 3 of 7
# ---Series SL_EMP_INJUR: Processing page 4 of 7
# ---Series SL_EMP_INJUR: Processing page 5 of 7
# ---Series SL_EMP_INJUR: Processing page 6 of 7
# ---Series SL_EMP_INJUR: Processing page 7 of 7
# created file 2019.Q1.G.03\Indicator_8.8.1_Series_SL_EMP_INJUR.json
